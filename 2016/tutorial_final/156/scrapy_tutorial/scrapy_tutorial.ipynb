# %% [markdown]
# ### Introduction ###
#
# ###### Some tips:
#
# (*This tutorial need to shift between several files to make everything works. So if you want to try it by your self, you can create all files from begining following this tutorial. But if you do not need to run it, you can just open the file directory of 'scrapy_tutorial' that I created already to get more details.  Good luck! *)
#
# This tutorial will introduce you **scrapy** which is a free and open-source web framework to help you crawling.
#
# Web crawling is the first step of data analysis. Before, we can use some packages to do this job like urllib2 and BeatifulSoup.But actually, BeatifulSoup is a parsing library which let you fetching contents from URL and parse certain parts of them. It cannot crawl unless you use a loop.
#
# Compared with BeatifulSoup, Scrapy is a complete framework that you can give it a root URL and then specify on how much URLs you want to crawl.
#
# Scrapy is written in python. You can use it to scrap the web or use it extract data by APIS. It is becoming much and much popular these days. Let's start!
#
# ### Tutorial content ###
# In this tutorial, we will show a brief step-by-step example of using Scrapy to scrap our school website http://www.cmu.edu/.
#
#
# We will cover the following topics in this tutorial:
# * [Installation](#1)
# * [Start a New Scrapy Project](#2)
# * [Create the first Spider](#3)
# * [Define Item](#4)
# * [Extract Data using Xpath](#5)
#    * [Extract html using scrapy shell](#5.1)
#    * [Extract html by function](#5.2)
# * [Improve the xpath search](#6)
#    * [Using Rules](#6.1)
#    * [Define attribute in the selector](#6.2)
# * [Store data in JSON form](#7)
# * [Item pipelines](#8)
#    * [Pipeline of drop and change data](#8.1)
#    * [Pipeline of storing data](#8.2)
#    * [Pipeline of droping duplicate data](#8.3)
#    * [Active the pipelines](#8.4)

# %% [markdown]
# <h3 id="1">1 Installation</h3>
#
# Since you have Python 2.7 or above installed. You can install Scrapy and its dependencies from Pypi with:

# %%
 $ pip install Scrapy

# %%
### run the above commands line
import commands
(status, output) = commands.getstatusoutput('pip install Scrapy')
print output
# Out:
# Requirement already satisfied (use --upgrade to upgrade): Scrapy in /anaconda/lib/python2.7/site-packages
# Requirement already satisfied (use --upgrade to upgrade): w3lib>=1.15.0 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): Twisted>=10.0.0 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): cssselect>=0.9 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): parsel>=0.9.3 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.5.2 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): PyDispatcher>=2.0.5 in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): queuelib in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): pyOpenSSL in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): lxml in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): service-identity in /anaconda/lib/python2.7/site-packages (from Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): zope.interface>=3.6.0 in /anaconda/lib/python2.7/site-packages (from Twisted>=10.0.0->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): cryptography>=1.3 in /anaconda/lib/python2.7/site-packages (from pyOpenSSL->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): pyasn1 in /anaconda/lib/python2.7/site-packages (from service-identity->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): attrs in /anaconda/lib/python2.7/site-packages (from service-identity->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): pyasn1-modules in /anaconda/lib/python2.7/site-packages (from service-identity->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): setuptools in /anaconda/lib/python2.7/site-packages/setuptools-23.0.0-py2.7.egg (from zope.interface>=3.6.0->Twisted>=10.0.0->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): idna>=2.0 in /anaconda/lib/python2.7/site-packages (from cryptography>=1.3->pyOpenSSL->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): enum34 in /anaconda/lib/python2.7/site-packages (from cryptography>=1.3->pyOpenSSL->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): ipaddress in /anaconda/lib/python2.7/site-packages (from cryptography>=1.3->pyOpenSSL->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): cffi>=1.4.1 in /anaconda/lib/python2.7/site-packages (from cryptography>=1.3->pyOpenSSL->Scrapy)
# Requirement already satisfied (use --upgrade to upgrade): pycparser in /anaconda/lib/python2.7/site-packages (from cffi>=1.4.1->cryptography>=1.3->pyOpenSSL->Scrapy)
# You are using pip version 8.1.2, however version 9.0.0 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# <h3 id="2">2 Start a New Scrapy Project</h3>
#
# Before you start scraping,you may need to start a new Scrapy Project. Enter a directory where you would like to store your code and run:

# %%
 $ scrapy startproject scrapy_tutorial

# %%
import commands
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy startproject scrapy_tutorial')
print output
# Out:
# New Scrapy project 'scrapy_tutoria', using template directory '//anaconda/lib/python2.7/site-packages/scrapy/templates/project', created in:
#     /Users/star/Desktop/CMU/Practical data science/tutorial/scrapy_tutorial/scrapy_tutoria
#
# You can start your first spider with:
#     cd scrapy_tutoria
#     scrapy genspider example example.com

# %% [markdown]
# The script creates a directory like this:

# %%
scrapy_tutorial/
    scrapy.cfg
    tutorial/
        __init__.py
        items.py
        pipelines.py
        settings.py
        spiders/
            __init__.py

# %% [markdown]
# <h3 id="3">3 Create the first Spider</h3>
#
# Spiders are some classes that need you to define. They subclass scrapy.Spider and define how you get links and how to parse content to extract data.
#
# The spider Subclass defindes some attributes and methods, one of them is parse() method.
# It is used to parses the response, extract data and find new URL to create new requests form them.
#
# Under the ** scrapy_tutorial/spiders ** directory in your project, create a new file. In this example, we create a new file named **“cmuspider.py”** to save our first Spider. Also, you can put this file(this notebook) under scrapy_tutorial/ directory for running.
#
# In this example, we want to start from school page of interdisciplinary programs to crawl all the program titles and links as an experienct to teach you how to use scrapy.
#
# In cmuspider.py file, we can write our spider like this:

# %%
import scrapy

class cmuSpider(scrapy.Spider):
    name = "cmu"
    allowed_domains = ["cmu.edu"] 
    
    def start_requests(self):
        # we choose cmu interdisciplinary-programs page to get programs information
        start_url= ['http://www.cmu.edu/academics/interdisciplinary-programs.html' ]  
        #if there are several start_urls, we can use loop
        for url in start_url:
            yield scrapy.Request(url=url, callback=self.parse) 
    def parse(self, response):
        page = response.url.split("/")[-1]
        with open(page, 'wb') as f: # save the result of scrawler in a file
            f.write(response.body)

# %% [markdown]
# Then, after fill the above code into the spider file, we can get html data!
#
# Go to scrapy_tutorial root and run:

# %%
    $ scrapy crawl cmu

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu')
print output
# Out:
# 2016-11-04 15:20:20 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 15:20:20 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'scrapy_tutorial'}
# 2016-11-04 15:20:20 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 15:20:20 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 15:20:20 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 15:20:20 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 15:20:20 [scrapy] INFO: Spider opened
# 2016-11-04 15:20:20 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 15:20:20 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 15:20:21 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 15:20:21 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 15:20:21 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 15:20:21 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 19, 20, 21, 153281),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 19, 20, 20, 966454)}
# 2016-11-04 15:20:21 [scrapy] INFO: Spider closed (finished)

# %% [markdown]
# After this, you get the whole html from the url you start. It is saved as "interdisciplinary-programs.html" as you hope.
#
# Part of the html file should like this:
#
# ![](http://i.imgur.com/6jNaagt.png)

# %% [markdown]
# <h3 id="3">4 Define Item</h3>
#
# We just get the whole html above. But most of time, in scraping we need to extract form typically unstructured sources.
#
# Scrapy can use Item class to return data like python dictionaries. But not like dicts that easy to typo in field name and get inconsistent data, Scrapy Item is better for big projects with many spiders.
#
# In this example, we need edit the **/item.py** file under directory of /scrapy_tutorial/ to define fields of these attributes like program_title, program_url from cmu programs site.

# %%
# paste the following class to the file "scrapy_tutorial/item.py"
class CmuItem(scrapy.Item):
    program_title = scrapy.Field()
    program_url = scrapy.Field()

# %% [markdown]
# <h3 id="5">5 Extract data by Xpath</h3>
#
#
# After defining the items, what we need to consider is how to extract the data we want to fill the item fields.
# In BeautifulSoup, we must deal with HTML tree. But in Scrapy, we uses **XPath**, which uses path expressions to select nodes or node-sets in an XML document.
#
#
# <h4 id="5.1">5.1 Extract html by scrapy shell</h4>
#
# Instead of using python file, we can use **Scrapy shell** to try first. Open your terminal and type in the url we will parse.

# %%
$ scrapy shell "http://www.cmu.edu/academics/interdisciplinary-programs.html"

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy shell "http://www.cmu.edu/academics/interdisciplinary-programs.html"')
print output
# Out:
# 2016-11-04 15:36:20 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 15:36:20 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'ROBOTSTXT_OBEY': True, 'DUPEFILTER_CLASS': 'scrapy.dupefilters.BaseDupeFilter', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'BOT_NAME': 'scrapy_tutorial', 'LOGSTATS_INTERVAL': 0}
# 2016-11-04 15:36:20 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 15:36:20 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 15:36:20 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 15:36:20 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 15:36:20 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 15:36:20 [scrapy] INFO: Spider opened
# 2016-11-04 15:36:20 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 15:36:20 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 15:36:20 [root] DEBUG: Using default logger
# 2016-11-04 15:36:20 [root] DEBUG: Using default logger
# [s] Available Scrapy objects:
# [s]   scrapy     scrapy module (contains scrapy.Request, scrapy.Selector, etc)
# [s]   crawler    <scrapy.crawler.Crawler object at 0x1045a4ad0>
# [s]   item       {}
# [s]   request    <GET http://www.cmu.edu/academics/interdisciplinary-programs.html>
# [s]   response   <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# [s]   settings   <scrapy.settings.Settings object at 0x1045a4b50>
# [s]   spider     <cmuSpider 'cmu' at 0x10498ef50>
# [s] Useful shortcuts:
# [s]   shelp()           Shell help (print this help)
# [s]   fetch(req_or_url) Fetch request (or URL) and update local objects
# [s]   view(response)    View response in a browser
# In [1]:
# Do you really want to exit ([y]/n)?

# %% [markdown]
# Once we get into the **scrapy shell**, we can use **xpath** to prase the html. Like we can get all **li** element using : **$ response.xpath('//li')**
#
#
# The output would like this:
#
# ![](http://i.imgur.com/TzW0ZBW.png)

# %% [markdown]
# Get the content of it by using:

# %%
$ response.xpath('//li').extract()

# %% [markdown]
# The output would like this:
#
# ![](http://i.imgur.com/hPtme8X.png)

# %% [markdown]
# <h4 id="5.2">5.2 Extract html by function</h4>
#
# Now we can change the parse function in spider before to get program titles and program links using **Xpath** method.
#
# Change the parse function in /cmuspider.py file under /spiders directory as the following:

# %%
## change the parse function in cmuspider.py to
def parse(self, response):
    for sel in response.xpath('//ul/li'):
        title = sel.xpath('a/text()').extract()
        link = sel.xpath('a/@href').extract()
    print title, link

# %%
Run it again:
    $ scrapy crawl cmu

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu')
print output
# Out:
# 2016-11-04 16:18:56 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 16:18:56 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'scrapy_tutorial'}
# 2016-11-04 16:18:56 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 16:18:56 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 16:18:56 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 16:18:56 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 16:18:56 [scrapy] INFO: Spider opened
# 2016-11-04 16:18:56 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 16:18:56 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 16:18:56 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 16:18:56 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 16:18:56 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 16:18:56 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 20, 18, 56, 392561),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 20, 18, 56, 224100)}
# 2016-11-04 16:18:56 [scrapy] INFO: Spider closed (finished)
# title,link
# [u'CMU Social Media Directory'] [u'../social-media/index.html']

# %% [markdown]
# From the output, we can get the title and links, but we need to return these extracted data to item. Item class that we defined before is easy to make a typo in a field name. They are simple containers used to collect the data.
#
# Next step is to change the spider to return the data to Item field:

# %%
# change the cmuspider.py file again to store item field by the following code:
import scrapy

from scrapy_tutorial.items import CmuItem  # don't forget to import CmuItem we defined before

class CmuSpider(scrapy.Spider):
    name = "cmu"
    allowed_domains = ["cmu.edu"]
    start_urls = [ "http://www.cmu.edu/academics/interdisciplinary-programs.html"]

    def parse(self, response):
        for sel in response.xpath('//ul/li'):
            item = CmuItem()
            item['program_title'] = sel.xpath('a/text()').extract()
            item['program_link'] = sel.xpath('a/@href').extract()
            print "program_title", item['program_title'] # just print to make it clear, you can delete it too.
            print "program_link",item['program_link']
            yield item

# %%
Run it again:
    $ scrapy crawl cmu

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu')
print output
# Out:
# 2016-11-04 17:16:42 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 17:16:42 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'scrapy_tutorial'}
# 2016-11-04 17:16:42 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 17:16:42 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 17:16:42 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 17:16:42 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 17:16:42 [scrapy] INFO: Spider opened
# 2016-11-04 17:16:42 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 17:16:42 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 17:16:42 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 17:16:42 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'index.html'],
#  'program_title': [u'                     Academics\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'interdisciplinary-programs.html'],
#  'program_title': [u'                     Interdisciplinary Programs\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.library.cmu.edu/'],
#  'program_title': [u'                     Libraries\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'learning-for-a-lifetime.html'],
#  'program_title': [u'                     Learning for a Lifetime\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../student-admission/index.html'],
#  'program_title': [u'                     Admission\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://admission.enrollment.cmu.edu/'],
#  'program_title': [u'                     Undergraduate Admission\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/graduate/admissions/'],
#  'program_title': [u'                     Graduate Admission\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/index.html'],
#  'program_title': [u'                     About\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/leadership/'],
#  'program_title': [u'                     Leadership\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/mission.html'],
#  'program_title': [u'                     Vision & Mission\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/history.html'],
#  'program_title': [u'                     History\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/traditions.html'],
#  'program_title': [u'                     Traditions\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/pittsburgh.html'],
#  'program_title': [u'                     Pittsburgh\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/rankings.html'],
#  'program_title': [u'                     Rankings\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../about/awards.html'],
#  'program_title': [u'                     Awards\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../visit/index.html'],
#  'program_title': [u'                     Visit\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../research/index.html'],
#  'program_title': [u'                     Research\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../research/centers-and-institutes.html'],
#  'program_title': [u'                     Centers & Institutes\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../student-experience/index.html'],
#  'program_title': [u'                     Student Experience\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://athletics.cmu.edu'],
#  'program_title': [u'                     Athletics\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.giving.cmu.edu/s/1410/giving/16/landing.aspx?sid=1410&gid=1&pgid=7010'],
#  'program_title': [u'                     Give Now\n    ']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/index.html'],
#  'program_title': [u'BXA Intercollege Degree Programs']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html'],
#  'program_title': [u'Computer Science and Arts (B.C.S.A.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html'],
#  'program_title': [u'Computational Biology\xa0(B.S. in Computational Biology)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.math.cmu.edu/%7Ebscf/'],
#  'program_title': [u'Computational Finance\xa0(B.S.C.F.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20'],
#  'program_title': []}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/hpp/index.html'],
#  'program_title': [u'Health Professions Program\xa0(HPP)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.hcii.cmu.edu/academics/hci-undergraduate'],
#  'program_title': [u'Human Computer Interaction\xa0(HCI) (secondary major)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html'],
#  'program_title': [u'Humanities and Arts (B.H.A.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/dietrich/hsp/'],
#  'program_title': [u'Humanities Scholars Program']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu'],
#  'program_title': [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/pages/undergraduate-programs'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html'],
#  'program_title': [u'Science and Arts (B.S.A.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/shs/'],
#  'program_title': [u'Science and Humanities Scholars Program']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cnbc.cmu.edu/training/graduate/'],
#  'program_title': [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html'],
#  'program_title': [u'Computational Biology (M.S.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance'],
#  'program_title': []}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html'],
#  'program_title': [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://estp.materials.cmu.edu/'],
#  'program_title': [u'Energy Science, Technology and Policy (EST&P) Program']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cit.cmu.edu/etim/'],
#  'program_title': [u'Engineering & Technology Innovation Management (E&TIM)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/index.html'],
#  'program_title': [u'Information Networking Institute Degrees']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html'],
#  'program_title': [u'Information Networking (M.S.I.N.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html',
#                   u'http://www.ini.cmu.edu/degrees/msis/index.html'],
#  'program_title': [u'Information Security (M.S.I.S.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx'],
#  'program_title': [u'Information Systems Management\xa0(M.I.S.M.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx'],
#  'program_title': [u'Information Technology\xa0(M.S.I.T.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Information Technology - Information Security (M.S.I.T.-IS)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html'],
#  'program_title': [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://www.mdphd.pitt.edu/'],
#  'program_title': [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Mobility (M.S.I.T. MOB)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html'],
#  'program_title': [u'Software Engineering Management (M.S.I.T. SEM)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html'],
#  'program_title': [u'Software Management (M.S. SM)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html'],
#  'program_title': [u'Technology Ventures (M.S.T.V.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx'],
#  'program_title': [u'Arts Management\xa0(M.A.M.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx'],
#  'program_title': [u'Entertainment Industry Management\xa0(MEIM)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.etc.cmu.edu/site/'],
#  'program_title': [u'Entertainment Technology\xa0(M.E.T.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://design.cmu.edu/content/master-design/'],
#  'program_title': [u'Master of Design\xa0(MDes)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/programs.php'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.mpd.cmu.edu/index.html'],
#  'program_title': [u'Product Design']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html'],
#  'program_title': [u'Machine Learning\xa0(ML Ph.D.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.afrotc.com/'],
#  'program_title': [u'Air Force ROTC']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.rotc.pitt.edu/'],
#  'program_title': [u'Army ROTC (with University of Pittsburgh)']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/nrotc/'],
#  'program_title': [u'Naval ROTC']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/events/'],
#  'program_title': [u'Calendar']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/jobs/'], 'program_title': [u'Careers']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../directory-contact/index.html'],
#  'program_title': [u'Directory/Contact']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../feedback/index.html'], 'program_title': [u'Feedback']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/global/presence/'],
#  'program_title': [u'Global Locations']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../health-safety/index.html'],
#  'program_title': [u'Health and Safety']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/news/'], 'program_title': [u'News']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../sitemap/index.html'], 'program_title': [u'Site Map']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/title-ix/'],
#  'program_title': [u'Title IX']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/legal/'],
#  'program_title': [u'Legal Info']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/'], 'program_title': [u'www.cmu.edu']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [], 'program_title': []}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.facebook.com/carnegiemellonu'],
#  'program_title': [u'CMU on Facebook']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.twitter.com/carnegiemellon'],
#  'program_title': [u'CMU on Twitter']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.linkedin.com/groupInvitation?groupID=2221&sharedKey=7BB90F3D4115'],
#  'program_title': [u'CMU on LinkedIn']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.youtube.com/carnegiemellonu'],
#  'program_title': [u'CMU YouTube Channel']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://itunes.apple.com/us/institution/carnegie-mellon-university/id383908951'],
#  'program_title': [u'CMU on iTunes U']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://instagram.com/carnegiemellon/'],
#  'program_title': [u'CMU on Instagram']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://www.flickr.com/photos/carnegiemellonu/'],
#  'program_title': [u'CMU on Flickr']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://weibo.com/cmualumni'],
#  'program_title': [u'CMU on Weibo']}
# 2016-11-04 17:16:42 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'../social-media/index.html'],
#  'program_title': [u'CMU Social Media Directory']}
# 2016-11-04 17:16:42 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 17:16:42 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 21, 16, 42, 810064),
#  'item_scraped_count': 89,
#  'log_count/DEBUG': 92,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 21, 16, 42, 595607)}
# 2016-11-04 17:16:42 [scrapy] INFO: Spider closed (finished)
# program_title [u'                     Academics\n    ']
# program_link [u'index.html']
# program_title [u'                     Interdisciplinary Programs\n    ']
# program_link [u'interdisciplinary-programs.html']
# program_title [u'                     Libraries\n    ']
# program_link [u'http://www.library.cmu.edu/']
# program_title [u'                     Learning for a Lifetime\n    ']
# program_link [u'learning-for-a-lifetime.html']
# program_title [u'                     Admission\n    ']
# program_link [u'../student-admission/index.html']
# program_title [u'                     Undergraduate Admission\n    ']
# program_link [u'http://admission.enrollment.cmu.edu/']
# program_title [u'                     Graduate Admission\n    ']
# program_link [u'http://www.cmu.edu/graduate/admissions/']
# program_title [u'                     About\n    ']
# program_link [u'../about/index.html']
# program_title [u'                     Leadership\n    ']
# program_link [u'http://www.cmu.edu/leadership/']
# program_title [u'                     Vision & Mission\n    ']
# program_link [u'../about/mission.html']
# program_title [u'                     History\n    ']
# program_link [u'../about/history.html']
# program_title [u'                     Traditions\n    ']
# program_link [u'../about/traditions.html']
# program_title [u'                     Pittsburgh\n    ']
# program_link [u'../about/pittsburgh.html']
# program_title [u'                     Rankings\n    ']
# program_link [u'../about/rankings.html']
# program_title [u'                     Awards\n    ']
# program_link [u'../about/awards.html']
# program_title [u'                     Visit\n    ']
# program_link [u'../visit/index.html']
# program_title [u'                     Research\n    ']
# program_link [u'../research/index.html']
# program_title [u'                     Centers & Institutes\n    ']
# program_link [u'../research/centers-and-institutes.html']
# program_title [u'                     Student Experience\n    ']
# program_link [u'../student-experience/index.html']
# program_title [u'                     Athletics\n    ']
# program_link [u'http://athletics.cmu.edu']
# program_title [u'                     Give Now\n    ']
# program_link [u'http://www.giving.cmu.edu/s/1410/giving/16/landing.aspx?sid=1410&gid=1&pgid=7010']
# program_title [u'BXA Intercollege Degree Programs']
# program_link [u'http://www.cmu.edu/interdisciplinary/index.html']
# program_title [u'Computer Science and Arts (B.C.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html']
# program_title [u'Computational Biology\xa0(B.S. in Computational Biology)']
# program_link [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html']
# program_title [u'Computational Finance\xa0(B.S.C.F.)']
# program_link [u'http://www.math.cmu.edu/%7Ebscf/']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20']
# program_title [u'Health Professions Program\xa0(HPP)']
# program_link [u'http://www.cmu.edu/hpp/index.html']
# program_title [u'Human Computer Interaction\xa0(HCI) (secondary major)']
# program_link [u'http://www.hcii.cmu.edu/academics/hci-undergraduate']
# program_title [u'Humanities and Arts (B.H.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html']
# program_title [u'Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/dietrich/hsp/']
# program_title [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']
# program_link [u'http://ideate.cmu.edu']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/pages/undergraduate-programs']
# program_title [u'Science and Arts (B.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html']
# program_title [u'Science and Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/shs/']
# program_title [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']
# program_link [u'http://www.cnbc.cmu.edu/training/graduate/']
# program_title [u'Computational Biology (M.S.)']
# program_link [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance']
# program_title [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Energy Science, Technology and Policy (EST&P) Program']
# program_link [u'http://estp.materials.cmu.edu/']
# program_title [u'Engineering & Technology Innovation Management (E&TIM)']
# program_link [u'http://www.cit.cmu.edu/etim/']
# program_title [u'Information Networking Institute Degrees']
# program_link [u'http://www.ini.cmu.edu/degrees/index.html']
# program_title [u'Information Networking (M.S.I.N.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html']
# program_title [u'Information Security (M.S.I.S.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html', u'http://www.ini.cmu.edu/degrees/msis/index.html']
# program_title [u'Information Systems Management\xa0(M.I.S.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx']
# program_title [u'Information Technology\xa0(M.S.I.T.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx']
# program_title [u'Information Technology - Information Security (M.S.I.T.-IS)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']
# program_link [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']
# program_link [u'https://www.mdphd.pitt.edu/']
# program_title [u'Mobility (M.S.I.T. MOB)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Software Engineering Management (M.S.I.T. SEM)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html']
# program_title [u'Software Management (M.S. SM)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html']
# program_title [u'Technology Ventures (M.S.T.V.)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html']
# program_title [u'Arts Management\xa0(M.A.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Entertainment Industry Management\xa0(MEIM)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx']
# program_title [u'Entertainment Technology\xa0(M.E.T.)']
# program_link [u'http://www.etc.cmu.edu/site/']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Master of Design\xa0(MDes)']
# program_link [u'http://design.cmu.edu/content/master-design/']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/programs.php']
# program_title [u'Product Design']
# program_link [u'http://www.mpd.cmu.edu/index.html']
# program_title [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Machine Learning\xa0(ML Ph.D.)']
# program_link [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html']
# program_title [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Air Force ROTC']
# program_link [u'http://www.afrotc.com/']
# program_title [u'Army ROTC (with University of Pittsburgh)']
# program_link [u'http://www.rotc.pitt.edu/']
# program_title [u'Naval ROTC']
# program_link [u'http://www.cmu.edu/nrotc/']
# program_title [u'Calendar']
# program_link [u'http://www.cmu.edu/events/']
# program_title [u'Careers']
# program_link [u'http://www.cmu.edu/jobs/']
# program_title [u'Directory/Contact']
# program_link [u'../directory-contact/index.html']
# program_title [u'Feedback']
# program_link [u'../feedback/index.html']
# program_title [u'Global Locations']
# program_link [u'http://www.cmu.edu/global/presence/']
# program_title [u'Health and Safety']
# program_link [u'../health-safety/index.html']
# program_title [u'News']
# program_link [u'http://www.cmu.edu/news/']
# program_title [u'Site Map']
# program_link [u'../sitemap/index.html']
# program_title [u'Title IX']
# program_link [u'http://www.cmu.edu/title-ix/']
# program_title [u'Legal Info']
# program_link [u'http://www.cmu.edu/legal/']
# program_title [u'www.cmu.edu']
# program_link [u'http://www.cmu.edu/']
# program_title []
# program_link []
# program_title [u'CMU on Facebook']
# program_link [u'http://www.facebook.com/carnegiemellonu']
# program_title [u'CMU on Twitter']
# program_link [u'http://www.twitter.com/carnegiemellon']
# program_title [u'CMU on LinkedIn']
# program_link [u'http://www.linkedin.com/groupInvitation?groupID=2221&sharedKey=7BB90F3D4115']
# program_title [u'CMU YouTube Channel']
# program_link [u'http://www.youtube.com/carnegiemellonu']
# program_title [u'CMU on iTunes U']
# program_link [u'http://itunes.apple.com/us/institution/carnegie-mellon-university/id383908951']
# program_title [u'CMU on Instagram']
# program_link [u'https://instagram.com/carnegiemellon/']
# program_title [u'CMU on Flickr']
# program_link [u'https://www.flickr.com/photos/carnegiemellonu/']
# program_title [u'CMU on Weibo']
# program_link [u'http://weibo.com/cmualumni']
# program_title [u'CMU Social Media Directory']
# program_link [u'../social-media/index.html']

# %% [markdown]
# <h3 id="6">6 Improve the xpath search</h3>
#
# From the output, we can find out that there is still something we need to do of the extract data:
#
#     a. The program we get contain the nevigation in the website such as "Centers & Institutes\n  "
#     b. The program we get contain the footer text in the website such as "CMU facebook".
#
# Since we only need the pure program list, we need to try to improve our **XPath** expression.
# Normally, we have several ways to do this:
# <h4 id="6.1">6.1 Using [Rules](https://doc.scrapy.org/en/latest/topics/spiders.html#crawling-rules)</h4>

# %%
# example of using rules:
# Since our example is crawling interdisciplinary-programs, we do not need to do this,
# you can try this code by yourself if interested.

class CmuSpider(CrawlSpider):
    name = 'cmu'
    allowed_domains = ['cmu.edu']
    start_urls = ['http://www.cmu.edu/academics/']
    rules = (
        # Extract inks matching 'category.php' (but not matching 'subsection.php')
        Rule(LinkExtractor(allow=('interdisciplinary-programs.html', ), deny=('learning-for-a-lifetime.html')))
    )

# %% [markdown]
# <h4 id="6.2">6.2 Define attribute in the selector</h4>
#
#   We can find out that in the website, all 'real' program titles and links are in class "". So we only need to change the selector line in cumspider.py file in /spiders directory:

# %%
# change the cmuspider.py file again to user better selector by the following code:
for sel in response.xpath('//div[@class=""]/ul/li'):

# %%
Run it again:
    $ scrapy crawl cmu

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu')
print output
# Out:
# 2016-11-04 17:55:50 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 17:55:50 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'scrapy_tutorial'}
# 2016-11-04 17:55:50 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 17:55:50 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 17:55:50 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 17:55:50 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 17:55:50 [scrapy] INFO: Spider opened
# 2016-11-04 17:55:50 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 17:55:50 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 17:55:50 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 17:55:50 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/index.html'],
#  'program_title': [u'BXA Intercollege Degree Programs']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html'],
#  'program_title': [u'Computer Science and Arts (B.C.S.A.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html'],
#  'program_title': [u'Computational Biology\xa0(B.S. in Computational Biology)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.math.cmu.edu/%7Ebscf/'],
#  'program_title': [u'Computational Finance\xa0(B.S.C.F.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20'],
#  'program_title': []}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/hpp/index.html'],
#  'program_title': [u'Health Professions Program\xa0(HPP)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.hcii.cmu.edu/academics/hci-undergraduate'],
#  'program_title': [u'Human Computer Interaction\xa0(HCI) (secondary major)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html'],
#  'program_title': [u'Humanities and Arts (B.H.A.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/dietrich/hsp/'],
#  'program_title': [u'Humanities Scholars Program']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu'],
#  'program_title': [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/pages/undergraduate-programs'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html'],
#  'program_title': [u'Science and Arts (B.S.A.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/shs/'],
#  'program_title': [u'Science and Humanities Scholars Program']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cnbc.cmu.edu/training/graduate/'],
#  'program_title': [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html'],
#  'program_title': [u'Computational Biology (M.S.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance'],
#  'program_title': []}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html'],
#  'program_title': [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://estp.materials.cmu.edu/'],
#  'program_title': [u'Energy Science, Technology and Policy (EST&P) Program']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cit.cmu.edu/etim/'],
#  'program_title': [u'Engineering & Technology Innovation Management (E&TIM)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/index.html'],
#  'program_title': [u'Information Networking Institute Degrees']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html'],
#  'program_title': [u'Information Networking (M.S.I.N.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html',
#                   u'http://www.ini.cmu.edu/degrees/msis/index.html'],
#  'program_title': [u'Information Security (M.S.I.S.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx'],
#  'program_title': [u'Information Systems Management\xa0(M.I.S.M.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx'],
#  'program_title': [u'Information Technology\xa0(M.S.I.T.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Information Technology - Information Security (M.S.I.T.-IS)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html'],
#  'program_title': [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://www.mdphd.pitt.edu/'],
#  'program_title': [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Mobility (M.S.I.T. MOB)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html'],
#  'program_title': [u'Software Engineering Management (M.S.I.T. SEM)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html'],
#  'program_title': [u'Software Management (M.S. SM)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html'],
#  'program_title': [u'Technology Ventures (M.S.T.V.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx'],
#  'program_title': [u'Arts Management\xa0(M.A.M.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx'],
#  'program_title': [u'Entertainment Industry Management\xa0(MEIM)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.etc.cmu.edu/site/'],
#  'program_title': [u'Entertainment Technology\xa0(M.E.T.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://design.cmu.edu/content/master-design/'],
#  'program_title': [u'Master of Design\xa0(MDes)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/programs.php'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.mpd.cmu.edu/index.html'],
#  'program_title': [u'Product Design']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html'],
#  'program_title': [u'Machine Learning\xa0(ML Ph.D.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.afrotc.com/'],
#  'program_title': [u'Air Force ROTC']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.rotc.pitt.edu/'],
#  'program_title': [u'Army ROTC (with University of Pittsburgh)']}
# 2016-11-04 17:55:50 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/nrotc/'],
#  'program_title': [u'Naval ROTC']}
# 2016-11-04 17:55:50 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 17:55:50 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 21, 55, 50, 497638),
#  'item_scraped_count': 47,
#  'log_count/DEBUG': 50,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 21, 55, 50, 308021)}
# 2016-11-04 17:55:50 [scrapy] INFO: Spider closed (finished)
# program_title [u'BXA Intercollege Degree Programs']
# program_link [u'http://www.cmu.edu/interdisciplinary/index.html']
# program_title [u'Computer Science and Arts (B.C.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html']
# program_title [u'Computational Biology\xa0(B.S. in Computational Biology)']
# program_link [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html']
# program_title [u'Computational Finance\xa0(B.S.C.F.)']
# program_link [u'http://www.math.cmu.edu/%7Ebscf/']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20']
# program_title [u'Health Professions Program\xa0(HPP)']
# program_link [u'http://www.cmu.edu/hpp/index.html']
# program_title [u'Human Computer Interaction\xa0(HCI) (secondary major)']
# program_link [u'http://www.hcii.cmu.edu/academics/hci-undergraduate']
# program_title [u'Humanities and Arts (B.H.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html']
# program_title [u'Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/dietrich/hsp/']
# program_title [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']
# program_link [u'http://ideate.cmu.edu']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/pages/undergraduate-programs']
# program_title [u'Science and Arts (B.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html']
# program_title [u'Science and Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/shs/']
# program_title [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']
# program_link [u'http://www.cnbc.cmu.edu/training/graduate/']
# program_title [u'Computational Biology (M.S.)']
# program_link [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance']
# program_title [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Energy Science, Technology and Policy (EST&P) Program']
# program_link [u'http://estp.materials.cmu.edu/']
# program_title [u'Engineering & Technology Innovation Management (E&TIM)']
# program_link [u'http://www.cit.cmu.edu/etim/']
# program_title [u'Information Networking Institute Degrees']
# program_link [u'http://www.ini.cmu.edu/degrees/index.html']
# program_title [u'Information Networking (M.S.I.N.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html']
# program_title [u'Information Security (M.S.I.S.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html', u'http://www.ini.cmu.edu/degrees/msis/index.html']
# program_title [u'Information Systems Management\xa0(M.I.S.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx']
# program_title [u'Information Technology\xa0(M.S.I.T.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx']
# program_title [u'Information Technology - Information Security (M.S.I.T.-IS)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']
# program_link [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']
# program_link [u'https://www.mdphd.pitt.edu/']
# program_title [u'Mobility (M.S.I.T. MOB)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Software Engineering Management (M.S.I.T. SEM)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html']
# program_title [u'Software Management (M.S. SM)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html']
# program_title [u'Technology Ventures (M.S.T.V.)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html']
# program_title [u'Arts Management\xa0(M.A.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Entertainment Industry Management\xa0(MEIM)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx']
# program_title [u'Entertainment Technology\xa0(M.E.T.)']
# program_link [u'http://www.etc.cmu.edu/site/']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Master of Design\xa0(MDes)']
# program_link [u'http://design.cmu.edu/content/master-design/']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/programs.php']
# program_title [u'Product Design']
# program_link [u'http://www.mpd.cmu.edu/index.html']
# program_title [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Machine Learning\xa0(ML Ph.D.)']
# program_link [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html']
# program_title [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Air Force ROTC']
# program_link [u'http://www.afrotc.com/']
# program_title [u'Army ROTC (with University of Pittsburgh)']
# program_link [u'http://www.rotc.pitt.edu/']
# program_title [u'Naval ROTC']
# program_link [u'http://www.cmu.edu/nrotc/']

# %% [markdown]
# <h3 id="7">7 Store data in JSON form</h3>
#
#
# So,after we get the data, how can we store the items?
#
# We can simply store the data as json. Enter the command:

# %%
$ scrapy crawl cmu -o items.json

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu -o programs.json')
print output
# Out:
# 2016-11-04 18:26:08 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 18:26:08 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'FEED_URI': 'programs.json', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'BOT_NAME': 'scrapy_tutorial', 'ROBOTSTXT_OBEY': True, 'FEED_FORMAT': 'json'}
# 2016-11-04 18:26:08 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 18:26:08 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 18:26:08 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 18:26:08 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-04 18:26:08 [scrapy] INFO: Spider opened
# 2016-11-04 18:26:08 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 18:26:08 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 18:26:08 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 18:26:08 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/index.html'],
#  'program_title': [u'BXA Intercollege Degree Programs']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html'],
#  'program_title': [u'Computer Science and Arts (B.C.S.A.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html'],
#  'program_title': [u'Computational Biology\xa0(B.S. in Computational Biology)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.math.cmu.edu/%7Ebscf/'],
#  'program_title': [u'Computational Finance\xa0(B.S.C.F.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20'],
#  'program_title': []}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/hpp/index.html'],
#  'program_title': [u'Health Professions Program\xa0(HPP)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.hcii.cmu.edu/academics/hci-undergraduate'],
#  'program_title': [u'Human Computer Interaction\xa0(HCI) (secondary major)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html'],
#  'program_title': [u'Humanities and Arts (B.H.A.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/dietrich/hsp/'],
#  'program_title': [u'Humanities Scholars Program']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu'],
#  'program_title': [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/pages/undergraduate-programs'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html'],
#  'program_title': [u'Science and Arts (B.S.A.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/shs/'],
#  'program_title': [u'Science and Humanities Scholars Program']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cnbc.cmu.edu/training/graduate/'],
#  'program_title': [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html'],
#  'program_title': [u'Computational Biology (M.S.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance'],
#  'program_title': []}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html'],
#  'program_title': [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://estp.materials.cmu.edu/'],
#  'program_title': [u'Energy Science, Technology and Policy (EST&P) Program']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cit.cmu.edu/etim/'],
#  'program_title': [u'Engineering & Technology Innovation Management (E&TIM)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/index.html'],
#  'program_title': [u'Information Networking Institute Degrees']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html'],
#  'program_title': [u'Information Networking (M.S.I.N.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html',
#                   u'http://www.ini.cmu.edu/degrees/msis/index.html'],
#  'program_title': [u'Information Security (M.S.I.S.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx'],
#  'program_title': [u'Information Systems Management\xa0(M.I.S.M.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx'],
#  'program_title': [u'Information Technology\xa0(M.S.I.T.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Information Technology - Information Security (M.S.I.T.-IS)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html'],
#  'program_title': [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://www.mdphd.pitt.edu/'],
#  'program_title': [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'Mobility (M.S.I.T. MOB)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html'],
#  'program_title': [u'Software Engineering Management (M.S.I.T. SEM)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html'],
#  'program_title': [u'Software Management (M.S. SM)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html'],
#  'program_title': [u'Technology Ventures (M.S.T.V.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx'],
#  'program_title': [u'Arts Management\xa0(M.A.M.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'Emerging Media\xa0(EM2)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx'],
#  'program_title': [u'Entertainment Industry Management\xa0(MEIM)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.etc.cmu.edu/site/'],
#  'program_title': [u'Entertainment Technology\xa0(M.E.T.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://design.cmu.edu/content/master-design/'],
#  'program_title': [u'Master of Design\xa0(MDes)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/programs.php'],
#  'program_title': [u'Music and Technology']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.mpd.cmu.edu/index.html'],
#  'program_title': [u'Product Design']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html'],
#  'program_title': [u'Machine Learning\xa0(ML Ph.D.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.afrotc.com/'],
#  'program_title': [u'Air Force ROTC']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.rotc.pitt.edu/'],
#  'program_title': [u'Army ROTC (with University of Pittsburgh)']}
# 2016-11-04 18:26:08 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/nrotc/'],
#  'program_title': [u'Naval ROTC']}
# 2016-11-04 18:26:08 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 18:26:08 [scrapy] INFO: Stored json feed (47 items) in: programs.json
# 2016-11-04 18:26:08 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 22, 26, 8, 947155),
#  'item_scraped_count': 47,
#  'log_count/DEBUG': 50,
#  'log_count/INFO': 8,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 22, 26, 8, 730516)}
# 2016-11-04 18:26:08 [scrapy] INFO: Spider closed (finished)
# program_title [u'BXA Intercollege Degree Programs']
# program_link [u'http://www.cmu.edu/interdisciplinary/index.html']
# program_title [u'Computer Science and Arts (B.C.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html']
# program_title [u'Computational Biology\xa0(B.S. in Computational Biology)']
# program_link [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html']
# program_title [u'Computational Finance\xa0(B.S.C.F.)']
# program_link [u'http://www.math.cmu.edu/%7Ebscf/']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20']
# program_title [u'Health Professions Program\xa0(HPP)']
# program_link [u'http://www.cmu.edu/hpp/index.html']
# program_title [u'Human Computer Interaction\xa0(HCI) (secondary major)']
# program_link [u'http://www.hcii.cmu.edu/academics/hci-undergraduate']
# program_title [u'Humanities and Arts (B.H.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html']
# program_title [u'Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/dietrich/hsp/']
# program_title [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']
# program_link [u'http://ideate.cmu.edu']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/pages/undergraduate-programs']
# program_title [u'Science and Arts (B.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html']
# program_title [u'Science and Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/shs/']
# program_title [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']
# program_link [u'http://www.cnbc.cmu.edu/training/graduate/']
# program_title [u'Computational Biology (M.S.)']
# program_link [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance']
# program_title [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Energy Science, Technology and Policy (EST&P) Program']
# program_link [u'http://estp.materials.cmu.edu/']
# program_title [u'Engineering & Technology Innovation Management (E&TIM)']
# program_link [u'http://www.cit.cmu.edu/etim/']
# program_title [u'Information Networking Institute Degrees']
# program_link [u'http://www.ini.cmu.edu/degrees/index.html']
# program_title [u'Information Networking (M.S.I.N.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html']
# program_title [u'Information Security (M.S.I.S.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html', u'http://www.ini.cmu.edu/degrees/msis/index.html']
# program_title [u'Information Systems Management\xa0(M.I.S.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx']
# program_title [u'Information Technology\xa0(M.S.I.T.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx']
# program_title [u'Information Technology - Information Security (M.S.I.T.-IS)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']
# program_link [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']
# program_link [u'https://www.mdphd.pitt.edu/']
# program_title [u'Mobility (M.S.I.T. MOB)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Software Engineering Management (M.S.I.T. SEM)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html']
# program_title [u'Software Management (M.S. SM)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html']
# program_title [u'Technology Ventures (M.S.T.V.)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html']
# program_title [u'Arts Management\xa0(M.A.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Entertainment Industry Management\xa0(MEIM)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx']
# program_title [u'Entertainment Technology\xa0(M.E.T.)']
# program_link [u'http://www.etc.cmu.edu/site/']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Master of Design\xa0(MDes)']
# program_link [u'http://design.cmu.edu/content/master-design/']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/programs.php']
# program_title [u'Product Design']
# program_link [u'http://www.mpd.cmu.edu/index.html']
# program_title [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Machine Learning\xa0(ML Ph.D.)']
# program_link [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html']
# program_title [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Air Force ROTC']
# program_link [u'http://www.afrotc.com/']
# program_title [u'Army ROTC (with University of Pittsburgh)']
# program_link [u'http://www.rotc.pitt.edu/']
# program_title [u'Naval ROTC']
# program_link [u'http://www.cmu.edu/nrotc/']

# %% [markdown]
# Then, we get a json file named **programs.json** and beautiful content with all programs titles and links that we need!
#
#
# ![](http://i.imgur.com/KejvrvP.png)

# %% [markdown]
# <h3 id='8'>8 Item pipelines</h3>
#
# Actually, we used the way of ** Item exporters** It is for serializing the scraped data. It is easy, and we can also store data by the form of XML, CSV and JSON lines.
#
# Besides **Feed Exports**, scrapy also provide **Pipelines** for use to store data. Each item pipeline is a Python class that implements a method. Besides we can use pipelines to drop the duplicate items or change the data we get:
#
# <h4 id='8.1'>8.1 Pipeline of drop and change data</h4>
# Here is an example to change the data by adding "CMU_program:" to every program title, let's find out how pipeline can do this task!

# %%
# Change your pipelines.py file to:

import json
from scrapy.exceptions import DropItem
class AddPipeline(object):
    def process_item(self, item, spider):
        vat_factor = "CMU_program: " # the factor we need to add before each program title
        if item['program_title']:
            if item['program_link']:
                item['program_title'][0]= vat_factor+ item['program_title'][0]
            return item
        else:
            raise DropItem("Missing project title in %s" % item)

# %% [markdown]
# <h4 id='8.2'>8.2 Pipeline of storing data</h4>
# By pipelines, we can also store items in different ways:
# * into Json File
# * into database
# * take screenshot of item
#
# Here is the example of store item into a JSON file named 'cmu.jl':

# %%
# add these to your pipelines.py file:
class JsonWriterPipeline(object):
    def __init__(self):
        self.file = open('cmu.jl', 'wb')
    def process_item(self, item, spider):
        line = json.dumps(dict(item)) + "\n"
        self.file.write(line)
        return item

# %% [markdown]
# <h4 id='8.3'>8.3 Pipeline of droping duplicate data</h4>
#
# By pipelines, you can also drop the duplicate items, use pipeline as a filter.Everytime pipe get a duplicate item, it will drop it.
# Here we can add a new pipeline:

# %%
from scrapy.exceptions import DropItem

class DuplicatesPipeline(object):
    def __init__(self):
        self.ids_seen = set()
    def process_item(self, item, spider):
        if item['program_title'][0] in self.ids_seen:
            raise DropItem("Duplicate item found: %s" % item['program_title'])
        else:
            self.ids_seen.add(item['program_title'][0])
            return item

# %% [markdown]
# <h4 id='8.4'>8.4 Active the pipelines </h4>
#
# Then you need to change the ** setting.py file ** to make our pipeline works.
#
# By define the integer values, you can determine the order these pipes run in.The order is from number low to high.
# In the example below, we run AddPipeline first, than jsonwriter pipeline.
#
# Add the following line to your setting.py file under /scrapy_tutorial directory:

# %%
# add this line to your setting.py file 
ITEM_PIPELINES = {'scrapy_tutorial.pipelines.AddPipeline':200,
'scrapy_tutorial.pipelines.JsonWriterPipeline': 400,
                  'scrapy_tutorial.pipelines.DuplicatesPipeline': 300
}

# %%
We can test if these pipes work by running it again:
    $ scrapy crawl cmu

# %%
### run the above commands line
(status, output) = commands.getstatusoutput('scrapy crawl cmu')
print output
# Out:
# 2016-11-04 19:41:17 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapy_tutorial)
# 2016-11-04 19:41:17 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'scrapy_tutorial.spiders', 'SPIDER_MODULES': ['scrapy_tutorial.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'scrapy_tutorial'}
# 2016-11-04 19:41:17 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-04 19:41:17 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-04 19:41:17 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-04 19:41:17 [scrapy] INFO: Enabled item pipelines:
# ['scrapy_tutorial.pipelines.AddPipeline',
#  'scrapy_tutorial.pipelines.DuplicatesPipeline',
#  'scrapy_tutorial.pipelines.JsonWriterPipeline']
# 2016-11-04 19:41:17 [scrapy] INFO: Spider opened
# 2016-11-04 19:41:17 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-04 19:41:17 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-04 19:41:17 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/robots.txt> (referer: None)
# 2016-11-04 19:41:17 [scrapy] DEBUG: Crawled (200) <GET http://www.cmu.edu/academics/interdisciplinary-programs.html> (referer: None)
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/index.html'],
#  'program_title': [u'CMU_program: BXA Intercollege Degree Programs']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html'],
#  'program_title': [u'CMU_program: Computer Science and Arts (B.C.S.A.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html'],
#  'program_title': [u'CMU_program: Computational Biology\xa0(B.S. in Computational Biology)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.math.cmu.edu/%7Ebscf/'],
#  'program_title': [u'CMU_program: Computational Finance\xa0(B.S.C.F.)']}
# 2016-11-04 19:41:17 [scrapy] WARNING: Dropped: Missing project title in {'program_link': [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20'],
#  'program_title': []}
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20'],
#  'program_title': []}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/hpp/index.html'],
#  'program_title': [u'CMU_program: Health Professions Program\xa0(HPP)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.hcii.cmu.edu/academics/hci-undergraduate'],
#  'program_title': [u'CMU_program: Human Computer Interaction\xa0(HCI) (secondary major)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html'],
#  'program_title': [u'CMU_program: Humanities and Arts (B.H.A.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/dietrich/hsp/'],
#  'program_title': [u'CMU_program: Humanities Scholars Program']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu'],
#  'program_title': [u'CMU_program: Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.music.cmu.edu/pages/undergraduate-programs'],
#  'program_title': [u'CMU_program: Music and Technology']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html'],
#  'program_title': [u'CMU_program: Science and Arts (B.S.A.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/shs/'],
#  'program_title': [u'CMU_program: Science and Humanities Scholars Program']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cnbc.cmu.edu/training/graduate/'],
#  'program_title': [u'CMU_program: Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html'],
#  'program_title': [u'CMU_program: Computational Biology (M.S.)']}
# 2016-11-04 19:41:17 [scrapy] WARNING: Dropped: Missing project title in {'program_link': [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance'],
#  'program_title': []}
# {'program_link': [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance'],
#  'program_title': []}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html'],
#  'program_title': [u'CMU_program: Embedded Software Engineering\xa0(M.S.I.T.-ESE)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'CMU_program: Emerging Media\xa0(EM2)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://estp.materials.cmu.edu/'],
#  'program_title': [u'CMU_program: Energy Science, Technology and Policy (EST&P) Program']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cit.cmu.edu/etim/'],
#  'program_title': [u'CMU_program: Engineering & Technology Innovation Management (E&TIM)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/index.html'],
#  'program_title': [u'CMU_program: Information Networking Institute Degrees']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html'],
#  'program_title': [u'CMU_program: Information Networking (M.S.I.N.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/msin/index.html',
#                   u'http://www.ini.cmu.edu/degrees/msis/index.html'],
#  'program_title': [u'CMU_program: Information Security (M.S.I.S.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx'],
#  'program_title': [u'CMU_program: Information Systems Management\xa0(M.I.S.M.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx'],
#  'program_title': [u'CMU_program: Information Technology\xa0(M.S.I.T.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'CMU_program: Information Technology - Information Security (M.S.I.T.-IS)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html'],
#  'program_title': [u'CMU_program: Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'CMU_program: Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'https://www.mdphd.pitt.edu/'],
#  'program_title': [u'CMU_program: Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html'],
#  'program_title': [u'CMU_program: Mobility (M.S.I.T. MOB)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html'],
#  'program_title': [u'CMU_program: Software Engineering Management (M.S.I.T. SEM)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html'],
#  'program_title': [u'CMU_program: Software Management (M.S. SM)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html'],
#  'program_title': [u'CMU_program: Technology Ventures (M.S.T.V.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx'],
#  'program_title': [u'CMU_program: Arts Management\xa0(M.A.M.)']}
# 2016-11-04 19:41:17 [scrapy] WARNING: Dropped: Duplicate item found: [u'CMU_program: Emerging Media\xa0(EM2)']
# {'program_link': [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/'],
#  'program_title': [u'CMU_program: Emerging Media\xa0(EM2)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx'],
#  'program_title': [u'CMU_program: Entertainment Industry Management\xa0(MEIM)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.etc.cmu.edu/site/'],
#  'program_title': [u'CMU_program: Entertainment Technology\xa0(M.E.T.)']}
# 2016-11-04 19:41:17 [scrapy] WARNING: Dropped: Duplicate item found: [u'CMU_program: Integrated Innovation for Products & Services (M.I.I. PS)']
# {'program_link': [u'http://www.cmu.edu/mpd/'],
#  'program_title': [u'CMU_program: Integrated Innovation for Products & Services (M.I.I. PS)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://design.cmu.edu/content/master-design/'],
#  'program_title': [u'CMU_program: Master of Design\xa0(MDes)']}
# 2016-11-04 19:41:17 [scrapy] WARNING: Dropped: Duplicate item found: [u'CMU_program: Music and Technology']
# {'program_link': [u'http://www.music.cmu.edu/programs.php'],
#  'program_title': [u'CMU_program: Music and Technology']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.mpd.cmu.edu/index.html'],
#  'program_title': [u'CMU_program: Product Design']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'CMU_program: Computational Biology\xa0(CPCB) (with University of Pittsburgh)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html'],
#  'program_title': [u'CMU_program: Machine Learning\xa0(ML Ph.D.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.compbio.cmu.edu/'],
#  'program_title': [u'CMU_program: Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.afrotc.com/'],
#  'program_title': [u'CMU_program: Air Force ROTC']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.rotc.pitt.edu/'],
#  'program_title': [u'CMU_program: Army ROTC (with University of Pittsburgh)']}
# 2016-11-04 19:41:17 [scrapy] DEBUG: Scraped from <200 http://www.cmu.edu/academics/interdisciplinary-programs.html>
# {'program_link': [u'http://www.cmu.edu/nrotc/'],
#  'program_title': [u'CMU_program: Naval ROTC']}
# 2016-11-04 19:41:17 [scrapy] INFO: Closing spider (finished)
# 2016-11-04 19:41:17 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 6373,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 4, 23, 41, 17, 751210),
#  'item_dropped_count': 5,
#  'item_dropped_reasons_count/DropItem': 5,
#  'item_scraped_count': 42,
#  'log_count/DEBUG': 45,
#  'log_count/INFO': 7,
#  'log_count/WARNING': 5,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 4, 23, 41, 17, 555613)}
# 2016-11-04 19:41:17 [scrapy] INFO: Spider closed (finished)
# program_title [u'BXA Intercollege Degree Programs']
# program_link [u'http://www.cmu.edu/interdisciplinary/index.html']
# program_title [u'Computer Science and Arts (B.C.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bcsaprogram.html']
# program_title [u'Computational Biology\xa0(B.S. in Computational Biology)']
# program_link [u'http://www.cbd.cmu.edu/education/bs-in-computational-biology.html']
# program_title [u'Computational Finance\xa0(B.S.C.F.)']
# program_link [u'http://www.math.cmu.edu/%7Ebscf/']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/undergraduate/economics%20']
# program_title [u'Health Professions Program\xa0(HPP)']
# program_link [u'http://www.cmu.edu/hpp/index.html']
# program_title [u'Human Computer Interaction\xa0(HCI) (secondary major)']
# program_link [u'http://www.hcii.cmu.edu/academics/hci-undergraduate']
# program_title [u'Humanities and Arts (B.H.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bhaprogram.html']
# program_title [u'Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/dietrich/hsp/']
# program_title [u'Integrative Design, Arts and Technology Network: IDeATe (minors and concentrations)']
# program_link [u'http://ideate.cmu.edu']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/pages/undergraduate-programs']
# program_title [u'Science and Arts (B.S.A.)']
# program_link [u'http://www.cmu.edu/interdisciplinary/programs/bsaprogram.html']
# program_title [u'Science and Humanities Scholars Program']
# program_link [u'http://www.cmu.edu/shs/']
# program_title [u'Center for the Neural Basis of Cognition (CNBC) Graduate Training Programs']
# program_link [u'http://www.cnbc.cmu.edu/training/graduate/']
# program_title [u'Computational Biology (M.S.)']
# program_link [u'http://www.cmu.edu/bio/graduate/prospective_students/ms_comp_bio/program_description.html']
# program_title []
# program_link [u'http://tepper.cmu.edu/prospective-students/masters/masters-in-computational-finance']
# program_title [u'Embedded Software Engineering\xa0(M.S.I.T.-ESE)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web3-programs/MSIT-ESE/index.html']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Energy Science, Technology and Policy (EST&P) Program']
# program_link [u'http://estp.materials.cmu.edu/']
# program_title [u'Engineering & Technology Innovation Management (E&TIM)']
# program_link [u'http://www.cit.cmu.edu/etim/']
# program_title [u'Information Networking Institute Degrees']
# program_link [u'http://www.ini.cmu.edu/degrees/index.html']
# program_title [u'Information Networking (M.S.I.N.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html']
# program_title [u'Information Security (M.S.I.S.)']
# program_link [u'http://www.ini.cmu.edu/degrees/msin/index.html', u'http://www.ini.cmu.edu/degrees/msis/index.html']
# program_title [u'Information Systems Management\xa0(M.I.S.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-systems-management-mism/index.aspx']
# program_title [u'Information Technology\xa0(M.S.I.T.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-information-systems-and-management/information-technology-msit/index.aspx']
# program_title [u'Information Technology - Information Security (M.S.I.T.-IS)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Information Technology - Information Security (Kobe M.S.I.T.-IS) Dual Degree']
# program_link [u'http://www.ini.cmu.edu/degrees/kobe_msit-is/index.html']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Medical Scientist Training Program (M.S.T.P.) (with University of Pittsburgh)']
# program_link [u'https://www.mdphd.pitt.edu/']
# program_title [u'Mobility (M.S.I.T. MOB)']
# program_link [u'http://www.ini.cmu.edu/degrees/psv_msit/index.html']
# program_title [u'Software Engineering Management (M.S.I.T. SEM)']
# program_link [u'http://mse.isri.cmu.edu/software-engineering/web4-distance/MSIT-SEM/index.html']
# program_title [u'Software Management (M.S. SM)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mssm/index.html']
# program_title [u'Technology Ventures (M.S.T.V.)']
# program_link [u'http://www.cmu.edu/integrated-innovation/degrees/mstv/index.html']
# program_title [u'Arts Management\xa0(M.A.M.)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/arts-management-mam/index.aspx']
# program_title [u'Emerging Media\xa0(EM2)']
# program_link [u'http://ideate.cmu.edu/graduate-programs-research/emerging-media/']
# program_title [u'Entertainment Industry Management\xa0(MEIM)']
# program_link [u'http://www.heinz.cmu.edu/school-of-public-policy-management/entertainment-industry-management-meim/index.aspx']
# program_title [u'Entertainment Technology\xa0(M.E.T.)']
# program_link [u'http://www.etc.cmu.edu/site/']
# program_title [u'Integrated Innovation for Products & Services (M.I.I. PS)']
# program_link [u'http://www.cmu.edu/mpd/']
# program_title [u'Master of Design\xa0(MDes)']
# program_link [u'http://design.cmu.edu/content/master-design/']
# program_title [u'Music and Technology']
# program_link [u'http://www.music.cmu.edu/programs.php']
# program_title [u'Product Design']
# program_link [u'http://www.mpd.cmu.edu/index.html']
# program_title [u'Computational Biology\xa0(CPCB) (with University of Pittsburgh)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Machine Learning\xa0(ML Ph.D.)']
# program_link [u'http://www.ml.cmu.edu/prospective-students/ml-phd.html']
# program_title [u'Ph.D. Program in Strategy, Entrepreneurship, and Technological Change\xa0(TEC Ph.D.)']
# program_link [u'http://www.compbio.cmu.edu/']
# program_title [u'Air Force ROTC']
# program_link [u'http://www.afrotc.com/']
# program_title [u'Army ROTC (with University of Pittsburgh)']
# program_link [u'http://www.rotc.pitt.edu/']
# program_title [u'Naval ROTC']
# program_link [u'http://www.cmu.edu/nrotc/']

# %% [markdown]
# After add three pipelines here, we get different data compared with before's.
#
# We drop the duplicate ones(shown in log):
#
#   ![](http://i.imgur.com/kwrvJoZ.png)
#
#  Also, we add "CMU_program: " before every title as we hoped:
#
#
#   ![](http://i.imgur.com/sJ66zrH.png)

# %% [markdown]
# The above pipeline store data into JSON form, but if you are interested, you can also try to store data to MongoDB or MySQL.

# %% [markdown]
# ### Summary ###

# %% [markdown]
# After this little example of using scrapy library to crawl data from cmu website, we had a basic knowledge about how to get data from complex html, how improve our result of extracting, how to store data to simple JSON as well as how to drop or change data by adding pipelines. These basic knowledge can support you to try a project of crawling by yourself. But if you still need to learn more about scrapy, it would be helpful to read scrapy official tutorial in detials.
#
# Try to use scrapy and have fun!

# %% [markdown]
# ### References¶###
#
# Scrapy Tutorial https://doc.scrapy.org/en/latest/intro/tutorial.html
#
# A quick introduction to web crawling using Scrapy https://amaral.northwestern.edu/blog/quick-introduction-web-crawling-using-scrapy-part-
