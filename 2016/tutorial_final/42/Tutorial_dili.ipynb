# %% [markdown]
# # Image Processing & OpenCV

# %% [markdown]
# ## Outline

# %% [markdown]
# 1. Introduction
# 2. Warm up
# 3. OpenCV
#     - How to install OpenCV
#     - Basic operations
#     -

# %% [markdown]
# ## Introduction:

# %% [markdown]
# After taking a photo, we are so used to use some apps to add some photo effects or do some filter. In fact,a digital image is nothing more than a bunch of datas which indicating variations of red, green, and blue at a particular location on a grid of pixels. Most of the time, we just view this pixels as miniature rectangles and with little creative thinking on making some lower level maniupulation of pixels with code. In this tutorial, we will work on such pixels. Also, I will introduce `OpenCV` (Open Source Computer Vision),which is a library of programming functions mainly aimed at real-time computer vision.

# %% [markdown]
# ## Warm up

# %% [markdown]
# In the first part, we will work with `PIL`, `numpy`, `matplotlib`, and have an overview on image data.

# %%
# setup library imports
# import matplotlib.pyplot as plt
import numpy as np
import PIL
from PIL import Image

# %%
# load image from a image file
image = Image.open('buggy.jpg')
# change image pixel data to a three dimensional array 
image_array = np.asarray(image)

# %%
print image_array

# %% [markdown]
# Sample Output(shorten):
# ```python
#
#         [[[  8  14  14]
#   [  6  12  12]
#   [  4  10   8]
#   ...,
#   [108  19  13]
#   [113  22  19]
#   [117  26  25]]
#
#  [[  9  13  12]
#   [  6  10   9]
#   [  5   9   8]
#   ...,
#  [[ 94 117 125]
#   [ 97 115 125]
#   [100 117 127]
#   ...,
#   [168 165 158]
#   [168 164 155]
#   [168 163 157]]]
# ```

# %% [markdown]
# The output is a  `three dimensional array `, which is an array within an array within an array. The outside dimension is the whole image, the second dimension correspond to each row, and the third dimension represent each pixel in that row. The inner list like ```python [ 73  71  30]  ``` is a `rgb` (red, green, blue) reprensentation. Some time the inner may like ```python [ 73  71  30 0]  ```,which is a `rgba` (red, green, blue,alpha) reprensentation.

# %%
#generate and show image from a three dimensional rbga array
plt.imshow(image_array)
plt.show()

# %% [markdown]
# Sample Output:
# <img src="buggy.jpg", height="200" width="400">

# %%
# print out width, height and total pixel number of the image
width, height = image.size
print "width: ", width
print "height: ", height
print "total pixel: ", width* height
# Out:
# width:  4454
# height:  2505
# total pixel:  11157270

# %% [markdown]
# Output:
# ```python
# width:  4454
# height:  2505
# total pixel:  11157270
# ```
# So even though we can get a pixel array from an image, since the size of that array is big, the computational cost is really expensive when manipulating the pixel array directly. So we need some more powerful tool to deal with these pixel data and have some amazing output. `OpenCV` is a great tool in this situation, and in the following part, we will talk about `openCV - Pyhton`.

# %% [markdown]
# ## OpenCV

# %%
new_array =[[[0, 255, 0],[0, 255, 0],[0, 255, 0]],[[255, 0, 0],[0, 255, 0],[0, 255, 0]]]
plt.imshow(new_array)
plt.show()

# %% [markdown]
# ### Install OpenCV-Python

# %% [markdown]
# - Installation in Mac
#      * Since we have already installed the Anaconda platform, we can open a new terminal window and type:
# ```bash
#         conda install -c https://conda.binstar.org/menpo opencv
# ```
#
#   * If you don’t use Anaconda, then you can follow [https://www.youtube.com/watch?v=37RvqZVddAw](https://www.youtube.com/watch?v=37RvqZVddAw) to do the installation.
#
#
#  - Installation in Windows
#
#      * PC user can follow this link if you have already installed the Anaconda:
#      http://mathalope.co.uk/2015/05/07/opencv-python-how-to-install-opencv-python-package-to-anaconda-windows/
#
#      * If not, then you can follow this link:
#      http://docs.opencv.org/2.4/doc/tutorials/introduction/windows_install/windows_install.html
#
# Unlike `matplotlib`, `numpy` and other packages we used before, it may take a while to figure out how to install openCV, but later you will find this tool is really powerful when deal with computer vision.

# %% [markdown]
# ### Overview

# %% [markdown]
# `OpenCV-Python` is a library of Python bindings designed to solve computer vision problems.
#
# `OpenCV-Python` makes use of `Numpy`, which is a highly optimized library for numerical operations with a `MATLAB-style syntax`. All the `OpenCV` array structures are converted to and from Numpy arrays. This also makes it easier to integrate with other libraries that use `Numpy` such as `SciPy` and `Matplotlib`.

# %% [markdown]
# ### Basic Operations on Images

# %% [markdown]
# First, we will learn how to read,display, and save an image.
#
# - Read an image: `cv2.imread()`
#
# - Show an image: `cv2.imshow() `
#
# - Save an image: `cv2.imwrite() `

# %%
# setup library imports
import cv2
#Load buggy image
img_buggy = cv2.imread('buggy.jpg')
# your can try the below part by yourself
# TRY YOURSELF START
#Display an image in a window
# cv2.imshow('image',img_buggy)
#wait user to press any key
# cv2.waitKey(0)
#Destroys all the windows we created
# cv2.destroyAllWindows()

#TRY YOURSELF END

# %% [markdown]
# Then we will do some basic operations on the images. We can access a pixel value by its row and column coordinates.
#
# **Importance notice: In openCV, pixel's representation is BGR (blue,green, red), instead of RGB(red,green,blue)**
#
# Image processing usually follow the below procedure：
# - load image in color mode:  `cv2.imread('image.jpg',cv2.IMREAD_COLOR)`
# - convert image to grayscale mode:  `cv2.cvtColor(image,cv2.COLOR_BGR2GRAY) `
# - doing image analysis
# - apply the output back to the colored image and display

# %% [markdown]
# In the following part, we will begin to do some fancy things.
#
# In the next block, I want to put the CMU logo on the top-left corner of the buggy image.

# %%
# Load two images
buggy_img = cv2.imread('buggy.jpg')
logo_img = cv2.imread('logo.jpg')

# %% [markdown]
# After loading two images, since we want to put the logo on the top-left corner of the buggy image, we need to know the logo size and get a image region in buggy image, then later we can replace the image region with logo.In openCV, we can only add two image with same size.

# %%
# get the logo_image's size
rows,cols,channels = logo_img.shape
#then got a image region on the top-left corner of the buggy image
roi = buggy_img[0:rows, 0:cols ]

# %% [markdown]
# Then, we will convert the logo image from one color-space to another, in this case, from BGR to Gray. For BGR image, it returns an array of Blue, Green, Red values. For grayscale image, just corresponding intensity is returned.
#
# In OpenCV, there are three common color-space:  `BGR`, `GRAY` and `HSV`. For color conversion, we use the function `cv2.cvtColor(input_image, flag)` where `flag` determines the type of conversion.
#
# For `BGR` -> `Gray` conversion we use the flags `cv2.COLOR_BGR2GRAY`. Similarly for `BGR` -> `HSV`, we use the flag `cv2.COLOR_BGR2HSV`.
#
# **Note: ** For HSV, Hue range is [0,179], Saturation range is [0,255] and Value range is [0,255]. Different softwares use different scales. So if you are comparing OpenCV values with them, you need to normalize these ranges.
#
#
# _Why do we convert the color-space:_
# - Grayscale image, just corresponding to the intensity. In our case, we want to cut out the logo part from the logo image, so we can only manipulate based on the intensity and it save memory and running time.
# - In HSV, it is more easier to represent a color than RGB color-space. So if we want to focus on the color part, we can covert to HSV space.

# %%
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(logo_img,cv2.COLOR_BGR2GRAY)

# %% [markdown]
# We often use threshold when dealing with grayscale image. Below is the pseudo code of a general thresholding.
#
# **Thresholding rule:**
# ```python
# if src(x,y) > thresh
#   dst(x,y) = maxValue
# else
#   dst(x,y) = 0
# ```
#
# After we got the binary thresholding, we can applying binary thresholding to the input image.

# %%
# create a binary thresholding
thresh = 125
maxValue = 255
ret, mask = cv2.threshold(img2gray, thresh, maxValue, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# apply thresholding to buggy image and black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask)

# apply thresholding to logo image and take only region of logo from logo image.
img2_fg = cv2.bitwise_and(logo_img,logo_img,mask = mask_inv)

# Put logo in ROI and modify the buggy image
# OpenCV can only add two image with same size
# So make sure the images' size are match
dst = cv2.add(img1_bg,img2_fg)
#if is also works if you can wrote dst = img1_bg + img2_fg
buggy_img[0:rows, 0:cols ] = dst

# cv2.imshow('res',buggy_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %% [markdown]
# Sample Input:
#
# - Logo image
# <img src="logo.jpg", height="200" width="400">
# - Buggy image:
# <img src="buggy.jpg", height="200" width="400">
#
# Sample Output:
# <img src="combined.png", height="200" width="400">

# %% [markdown]
# ### Face Detection using Haar Cascades

# %% [markdown]
# #### Introduction to Cascade of Classifiers

# %% [markdown]
# "Instead of applying all the 6000 features on a window, group the features into different stages of classifiers and apply one-by-one. (Normally first few stages will contain very less number of features). If a window fails the first stage, discard it. We don't consider remaining features on it. If it passes, apply the second stage of features and continue the process. The window which passes all stages is a face region." - citation from [Face Detection using Haar Cascades](http://www.bogotobogo.com/python/OpenCV_Python/python_opencv3_Image_Object_Detection_Face_Detection_Haar_Cascade_Classifiers.php)

# %% [markdown]
# <img src="cascade.png", height="200" width="400">     <center> -image source from [How Face Detection Works](http://www.cognotics.com/opencv/servo_2007_series/part_2/sidebar.html)</center>

# %% [markdown]
# #### Using OpenCV's pre-trained classifier

# %% [markdown]
# In the following part, we will see the basics of face detection using Haar Feature-based Cascade Classifiers. OpenCV already contains many pre-trained classifiers for face, eyes, smile etc. These XML files are stored in `opencv/data/haarcascades/` folder. So, in the next part, we will first use the provided classifier and do some simply face detection.

# %%
#Copy the 'haarcascade_frontalface_default.xml' into the current folder
# import the default face detection xml
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
#import the buggy image
buggy_img = cv2.imread('buggy.jpg')
# create grayscale mode image 
gray = cv2.cvtColor(buggy_img, cv2.COLOR_BGR2GRAY)

"""
cv2.CascadeClassifier.detectMultiScale(image[, scaleFactor[, minNeighbors[, flags[, minSize[, maxSize]]]]]) 
- image : Matrix of the type CV_8U containing an image where objects are detected.
- scaleFactor : Parameter specifying how much the image size is reduced at each image scale. 
Suppose, the scale factor is 1.03, it means we're using a small step for resizing, i.e. reduce size by 3 %, 
we increase the chance of a matching size with the model for detection is found, while it's expensive.
- minNeighbors : Parameter specifying how many neighbors each candidate rectangle should have to retain it. 
This parameter will affect the quality of the detected faces: higher value results in less detections but with higher quality. 
"""

faces = face_cascade.detectMultiScale(gray, 1.2, 3)
#If faces are found, it returns the positions of detected faces as Rect(x,y,w,h).
for (x,y,w,h) in faces:
    cv2.rectangle(buggy_img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = buggy_img[y:y+h, x:x+w]
cv2.imshow('img',buggy_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Sample output:
# <img src="buggy_found.jpg", height="200" width="400">

# %% [markdown]
# ### Create our own Haar Cascade

# %% [markdown]
# In the following part, we will make more fun and create our own Haar Cascade. We will construct a tartans's cascade classifier.

# %% [markdown]
# [image-net.org](http://image-net.org/) is a great website to find source images.
# For example, if we want to find some sample image which contains human faces.
# type "face" in the searching bar -> select the wanted Synsets -> click "Downloads" -> click "URLs",then we will get a webpage contains bunch of images' urls.
#
# We can use urllib2 for python2 or urllib for python3 fetch images automatically from these urls.

# %%
#import library
import urllib
import cv2
import numpy as np
import os

# %%
# in this method, fetched some animal's images
# and stored the resized and grayscale images into "neg" file 
#and we will use these images as background images 
def store_raw_images():
    neg_image_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n01316949'
    neg_image_urls=urllib.urlopen(neg_image_link).read().decode()
    if not os.path.exists('neg'):
        os.makedirs('neg')
    pic_num = 1
    for i in neg_image_urls.split('\n'):
        try:
            if pic_num <500:
                # print i can help us to see the progress 
                print i
                urllib.urlretrieve(i,"neg/"+str(pic_num)+".jpg")
                img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
                resized_img = cv2.resize(img,(100,100))
                cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_img)
                pic_num +=1
            else: 
                break
        except Exception as e:
            print (str(e))  
    
store_raw_images()
# Out:
# http://www.horse-chiropractor.com/animal-chiropractor/equine_chiropractor.jpg
# http://farm4.static.flickr.com/3142/2898261629_3af75a6fc0.jpg
# http://farm4.static.flickr.com/3091/3162253667_1ddaf0a06f.jpg
# http://www.bancoimagenes.com/cd738/cd738f155_a.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://static.andaluciaimagen.com/Burro-como-animal-de-transporte-51334.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://farm1.static.flickr.com/30/62940360_e2bc08a608.jpg
# http://www.engormix.com/images/s_articles/eficiencia03.jpg
# http://static.flickr.com/41/124541184_97729d713d.jpg
# http://perso.wanadoo.es/josanar620404/aAa.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3224/3107362693_994b7545f7.jpg
# http://farm1.static.flickr.com/79/252181133_3f5220e82a.jpg
# http://farm3.static.flickr.com/2368/1565633048_eda7291949.jpg
# http://www.teambuilding-horses.com/images/SCS%20web%20pics/RIclass.jpg
# http://farm4.static.flickr.com/3380/3218021686_df5c7dc70e.jpg
# http://farm2.static.flickr.com/1256/979001376_aaf2115324.jpg
# http://farm4.static.flickr.com/3011/2898257001_502f77e5e7.jpg
# http://farm3.static.flickr.com/2043/2271755015_5e6075274e.jpg
# http://farm4.static.flickr.com/3165/2363812771_81d2fb3709.jpg
# http://4.bp.blogspot.com/_4VQQ3cI4oFc/R72-om2quyI/AAAAAAAAAaQ/8L7RYzlLZWs/s320/bueyes.jpg
# http://3.bp.blogspot.com/_Bf0CoMAdCbE/SbQt0R7ju0I/AAAAAAAAAZs/b9r7o67uk7c/s320/ATT0097211.jpg
# http://farm1.static.flickr.com/192/463037922_115269f49f.jpg
# http://farm2.static.flickr.com/1372/1368905783_872166f25c.jpg
# http://www.esxm.com.cn/Files/adminfiles/esxm/200804/02%u6BCD%u6C34%u725B.gif
# [Errno socket error] [Errno 60] Operation timed out
# http://farm4.static.flickr.com/3053/2621650825_a262b14a6b.jpg
# http://www.ruralhistory.org/assets/interface_assets/windmill_assets/photos/work/work_animals/d71_29_008.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/82/275226096_8876deb8d9.jpg
# http://static.flickr.com/43/124541781_aaf807ba51.jpg
# http://junglewalk.com/animal-pictures/628/Horse-4837.jpg
# http://farm1.static.flickr.com/134/379910025_37dbc81471.jpg
# http://www.catie.ac.cr/BancoMedios/Imagenes/bol_feb08_gama6.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm3.static.flickr.com/2357/2069725614_1e74c073ec.jpg
# http://farm1.static.flickr.com/157/331374723_5d2b8d67cf.jpg
# http://static.flickr.com/1183/1442578233_5818d4ff6a.jpg
# http://farm1.static.flickr.com/235/460317629_5adbb575f6.jpg
# http://farm4.static.flickr.com/3455/3226630734_e1fa2138d4.jpg
# http://farm1.static.flickr.com/223/469958298_3a0b2da94e.jpg
# http://www.portaleureka.com/revista/images/stories/articulos/naturaleza/elefant2.jpg
# http://www.hartquarterhorses.com/files/images/animals%2010%20(2).jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://www.masseriacoppola.it/dap/images/p002_1_02.jpg
# http://www.curiositis.com/wp-content/uploads/animales/Burro.jpg
# http://farm3.static.flickr.com/2299/2256614248_8cfb4a054b.jpg
# http://static.flickr.com/2036/1572028598_8e0454e6c7.jpg
# http://farm4.static.flickr.com/3258/2567870235_571c1cb896.jpg
# http://imgsrc.baidu.com/baike/pic/item/ac2fc3c4de7db5de39db4999.jpg
# http://farm3.static.flickr.com/2182/2184029888_c3598ac2f7.jpg
# http://static.flickr.com/1057/1432442730_d4f8d9b2ff.jpg
# http://www.genelite.net/graphics/animal2f.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm2.static.flickr.com/1403/582250098_f6207adb49.jpg
# http://farm2.static.flickr.com/1432/723994206_729be5c157.jpg
# http://farm1.static.flickr.com/139/377134786_c4eafab97d.jpg
# http://farm2.static.flickr.com/1336/1002128627_8f1cb237bf.jpg
# http://farm3.static.flickr.com/2316/2367058930_b96df09c20.jpg
# http://farm1.static.flickr.com/232/550101422_8646370424.jpg
# http://farm1.static.flickr.com/197/460932860_ebcd956e21.jpg
# http://www.johnnahaskellphotos.com/gallery/Maine_Scenes/Animals/gallery_Work%20Horse2.jpg
# http://farm4.static.flickr.com/3048/2892448696_0f6b6b3f72.jpg
# http://farm4.static.flickr.com/3047/3069353275_55c0126052.jpg
# http://i.pbase.com/g3/40/826540/2/107991583.7h9N8oSJ.jpg
# http://farm4.static.flickr.com/3127/3163085492_37ff20fcc5.jpg
# http://farm3.static.flickr.com/2398/2256614244_3f3d2c2881.jpg
# http://www.camelidos.com.uy/imagenes/de%20carga.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://farm4.static.flickr.com/3124/3092330152_a6179be1af.jpg
# http://farm4.static.flickr.com/3106/3237252853_365261c286.jpg
# http://img364.imageshack.us/img364/4536/65burro24jk.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://www.mariapinto.es/imatec/imagenes/entorno_rural/burro.jpg
# http://www.cs.cmu.edu/~xc/images/favorite_animal_picture.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://ecosofia.org/files/elefantes.jpg
# http://farm4.static.flickr.com/3143/3079547507_cd07f603c9.jpg
# http://farm1.static.flickr.com/65/170499676_c7fb203f0c.jpg
# http://farm3.static.flickr.com/2046/2468340339_01ebdff82d.jpg
# http://farm1.static.flickr.com/218/460321019_00c7ca84a0.jpg
# http://farm4.static.flickr.com/3128/2691529037_1900f42da4.jpg
# http://www.neddi.org/wp-content/uploads/2008/10/heather-portrait-small.jpg
# http://farm3.static.flickr.com/2294/2074885451_6eeee4b240.jpg
# http://static.flickr.com/3182/2581467968_96ec2a96f7.jpg
# http://farm4.static.flickr.com/3542/3445751703_478909cc0a.jpg
# http://farm4.static.flickr.com/3186/2568912231_e3a56079b7.jpg
# http://farm1.static.flickr.com/12/14193211_9aff4f7b01.jpg
# http://1862.img.pp.sohu.com.cn/images/blog/2009/3/23/17/24/120dd753531g215.jpg
# http://www.nuevodiarioweb.com.ar/Uploads/2009124/imagenes/Size2/cb305cdd-7ee9-43af-99ca-acd565c5668b.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/210/523649759_baf12c4807.jpg
# http://farm1.static.flickr.com/189/463038576_9e91e39c4c.jpg
# http://4.bp.blogspot.com/_EXQmnFDC-XU/R_LTklzhS-I/AAAAAAAAANg/rC_JqD9wnjU/s320/c_decreto_06.JPG
# http://farm4.static.flickr.com/3254/3149183872_524d615489.jpg
# http://farm4.static.flickr.com/3109/3213204325_57ee490c2d.jpg
# http://www.euskonews.com/0279zbk/argazkiak/gaia27904_03.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://camyna.com/wp-content/uploads/2008/04/screenshot532.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3072/2839977857_2b22122430.jpg
# http://farm1.static.flickr.com/154/395427233_ba80b7a63d.jpg
# http://www.xavifernandezviatges.com/blog/wp-content/2009/03/bufalo-theodore-roosevel-n-p.jpg
# http://www.loomisbasinlargeanimal.com/reproduction.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm3.static.flickr.com/2092/2256614236_e5c1c0b9e4.jpg
# http://www.galeon.com/lagurulla/burru.jpg
# http://www.ellitoral.com/blogs/mascotas/wp-content/uploads/2007/10/litoral.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://www.freewebs.com/ponyscriaderomawill/shetland1.JPG
# http://img0.liveinternet.ru/images/attach/b/2/0/5/5992_Wojtek_KwiatkowskiShagya.jpg
# http://farm4.static.flickr.com/3585/3425138426_bf022938da.jpg
# http://farm1.static.flickr.com/40/108466971_52ba3cacdb.jpg
# http://www.siguaonline.com/Macho.jpg
# [Errno socket error] [Errno 54] Connection reset by peer
# http://farm4.static.flickr.com/3119/2905376815_f9a9c50636.jpg
# http://farm1.static.flickr.com/94/253850067_17c8038c13.jpg
# http://english.xsm.cn/work/animal/tanimal3.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://www.interempresas.net/FotosArtProductos/P25510.jpg
# http://farm1.static.flickr.com/190/463042247_aee8e72e96.jpg
# http://farm4.static.flickr.com/3036/3401275955_b703e56291.jpg
# http://farm1.static.flickr.com/227/463038544_2be861d120.jpg
# http://telecentros1.inictel.net/gallery2/main.php?g2_view=core.DownloadItem&g2_itemId=7429&g2_serialNumber=2
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://static.flickr.com/2399/2596323284_91e9b2a01a.jpg
# http://www.ranchoinmaculada.com/sitebuilder/images/torosfight-420x218.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://farm3.static.flickr.com/2177/1809462686_e5d7d6eb09.jpg
# http://www.clarin.com/diario/2006/10/28/um/thumb/salta2.jpg
# http://farm4.static.flickr.com/3211/3022226928_edb772935f.jpg
# http://farm1.static.flickr.com/146/380282731_7da8f592b4.jpg
# http://farm1.static.flickr.com/166/336748940_ee93a1ba22.jpg
# http://farm1.static.flickr.com/179/367661397_bd3b1c8949.jpg
# http://farm4.static.flickr.com/3196/2865847916_915a9a20a7.jpg
# http://animaltranslations.com/pan.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://imgsrc.baidu.com/baike/pic/item/7a8a144618abfb1a6a63e56d.jpg
# http://farm4.static.flickr.com/3068/2846658991_1e4c281180.jpg
# http://www.easyviajar.com/images/destination/PEROU/PEROU19/1.jpg
# http://farm1.static.flickr.com/201/450404975_760ebb44da.jpg
# http://farm3.static.flickr.com/2396/2434241647_06b94160f2.jpg
# http://farm1.static.flickr.com/199/463042043_0c65e5cc3b.jpg
# http://www.geocities.com/faunamundial/Fotos/elefante.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3073/2899102354_4f6132c960.jpg
# http://farm1.static.flickr.com/200/465495927_a32fc4ba17.jpg
# http://farm3.static.flickr.com/2041/2422803990_fed6e8ffa4.jpg
# http://farm4.static.flickr.com/3407/3176472179_f3fe9eccdc.jpg
# http://image03.webshots.com/3/6/35/11/16563511enKpktOBog_ph.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/120/256322921_9aab2b5a12.jpg
# http://images.xooob.com/20083622/200836221247924.jpg
# [Errno socket error] [Errno 60] Operation timed out
# http://farm2.static.flickr.com/1265/723115541_0a39714000.jpg
# http://farm4.static.flickr.com/3015/2898264517_efe6079b98.jpg
# http://farm4.static.flickr.com/3058/2362272834_0ebbeb45f5.jpg
# http://farm1.static.flickr.com/150/376254247_969fe0c40c.jpg
# http://farm1.static.flickr.com/158/414645901_b9ce53f145.jpg
# http://img248.imageshack.us/img248/4946/pujagueyvp9.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm2.static.flickr.com/1257/848337169_405cdeea31.jpg
# http://farm1.static.flickr.com/119/366712611_3607983fb6.jpg
# http://www.rebeccacroftstudios.com/images/paintings/animals/horses.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://www.hartquarterhorses.com/files/images/gray%20work%20horse.img_assist_custom.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3034/2869983186_23924e9f26.jpg
# http://farm2.static.flickr.com/1209/835646658_89e324a553.jpg
# http://farm4.static.flickr.com/3093/2568858087_5a32557aaf.jpg
# http://farm4.static.flickr.com/3424/3195827584_ca45ec1150.jpg
# http://farm1.static.flickr.com/172/463038648_003c286708.jpg
# http://static.flickr.com/3446/3261168376_e1636b6464.jpg
# http://roulvwang.com/UploadFile/infouppic/313888403.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3137/2869157029_acf25ac2cc.jpg
# http://farm4.static.flickr.com/3210/3150983667_e207594cb4.jpg
# http://farm1.static.flickr.com/252/458123798_a6595debd8.jpg
# http://farm1.static.flickr.com/56/158516268_796c3e047d.jpg
# http://farm2.static.flickr.com/1339/1264254479_8a9e7764e8.jpg
# http://farm4.static.flickr.com/3287/2796234722_e27c9dd3cd.jpg
# http://farm3.static.flickr.com/2317/2252820436_c129953d0f.jpg
# http://farm4.static.flickr.com/3162/2919940625_417b566bd5.jpg
# http://www.galeon.com/cabrera2/Sorraia.jpg
# http://farm1.static.flickr.com/7/7280919_d3ea513d0e.jpg
# http://www.delcaminoequestrian.com/images/warrior_balance_work.jpg
# [Errno socket error] [Errno 54] Connection reset by peer
# http://farm4.static.flickr.com/3187/2568694678_946eeaa9ca.jpg
# http://elefantes.anipedia.net/images/elefantes-asiaticos.jpg
# http://www.amishphoto.com/picturepages/11_T.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/71/156625707_46bdc7eab3.jpg
# http://farm4.static.flickr.com/3258/2319300050_8d52f4febe.jpg
# http://farm4.static.flickr.com/3207/3074346811_8161cecce1.jpg
# http://farm1.static.flickr.com/96/247370417_e217e7e11b.jpg
# http://www.heuresis.com.ar/ventajas_archivos/img_vaca7.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://www.galeon.com/cabrera2/tiro-irlandes.jpg
# http://3.bp.blogspot.com/_vxIUx3HKEVs/SKLmn1grBhI/AAAAAAAAAA4/8i_ow0pCcdY/s320/Imagen1.jpg
# http://static.flickr.com/171/401504372_5ef03cb6a2.jpg
# http://farm1.static.flickr.com/25/50784592_57d451c945.jpg
# http://www.uua.cn/Animal/UploadFiles/200603/20060323214331560.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://static.flickr.com/77/219080495_da1374720c.jpg
# http://farm4.static.flickr.com/3483/3273174791_2ea2cc8f2d.jpg
# http://farm3.static.flickr.com/2372/2255755479_0a0f1be2e7.jpg
# http://bp1.blogger.com/_p_hcT9iTnno/Rl732dlsK3I/AAAAAAAAAm4/dAezi_E6qP0/s400/0531_pro_caballo_retuertas.jpg
# http://static.flickr.com/3158/2899106832_c6acbf3fdc.jpg
# http://farm1.static.flickr.com/17/20503890_f60227990c.jpg
# http://farm1.static.flickr.com/68/158805520_2fbad24f58.jpg
# http://farm3.static.flickr.com/2058/2160127952_e533ff87d9.jpg
# http://farm3.static.flickr.com/2406/1788117646_2f39a2f959.jpg
# http://www.espacioblog.com/myfiles/mamporrero/elefante-africa_jpg_w400.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/39/124540943_11d14ac593.jpg
# http://www.rios-galegos.com/burro18.jpg
# http://farm2.static.flickr.com/1038/724002610_32f7038225.jpg
# http://farm3.static.flickr.com/2363/2091614405_4af4390f0e.jpg
# http://www.cuencarural.com/img/notas/img_t-1922.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3267/3142799299_745490d6c2.jpg
# http://farm4.static.flickr.com/3589/3292996197_892b178e40.jpg
# http://farm1.static.flickr.com/108/283624341_98ae2d28b2.jpg
# http://farm1.static.flickr.com/51/129614850_0b6f407442.jpg
# http://farm3.static.flickr.com/2159/2149447026_724ba41e2c.jpg
# http://farm3.static.flickr.com/2416/2032462181_903b9abe93.jpg
# http://animalpetdoctor.homestead.com/1800erie.jpg
# http://farm1.static.flickr.com/60/162895122_0c652c1315.jpg
# http://www.puerto-lumbreras.com/scorazon/images/F10.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm1.static.flickr.com/35/64171782_da5f573744.jpg
# http://farm4.static.flickr.com/3102/2568859083_854eeab45a.jpg
# http://farm1.static.flickr.com/186/384371040_f9382647ca.jpg
# http://farm4.static.flickr.com/3065/2569738184_a4d7671c19.jpg
# http://www.sheppardsoftware.com/content/animals/images/mammals/ox_c_work.jpg
# http://farm4.static.flickr.com/3355/3328979092_e17335b42c.jpg
# http://farm3.static.flickr.com/2032/2184020650_57b75cd6f7.jpg
# http://farm1.static.flickr.com/201/463038750_87d0cb5660.jpg
# http://farm4.static.flickr.com/3170/3093584480_9a067843b7.jpg
# http://farm4.static.flickr.com/3011/2944904768_99af76aa01_o.jpg
# http://farm4.static.flickr.com/3230/2848448329_b61d89181f.jpg
# http://farm4.static.flickr.com/3323/3342928925_818faffcb4.jpg
# http://farm1.static.flickr.com/93/247371364_8cdf52ed2d.jpg
# http://farm4.static.flickr.com/3061/2868522958_7013c93f86.jpg
# http://farm1.static.flickr.com/221/458145387_f69aac80b7.jpg
# http://farm1.static.flickr.com/93/247372097_9cc4989e7c.jpg
# http://www.andaluciaimagen.com/Burro-como-animal-de-transporte_51334.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3155/2711717567_ef389581e0.jpg
# http://static.andaluciaimagen.com/Caballos-de-carga--Gerona--48839.jpg
# [Errno socket error] [Errno 8] nodename nor servname provided, or not known
# http://ourohio.org/uploads/images/stories/home_gardens/animals/animals_horses2.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://www.va12345.com/Zr-blood/images/mutz.jpg
# [Errno socket error] [Errno 54] Connection reset by peer
# http://farm4.static.flickr.com/3128/2568857553_f56c34cc64.jpg
# http://farm2.static.flickr.com/1040/723997848_c87a02defe.jpg
# http://farm2.static.flickr.com/1013/1414136162_b4c880d803.jpg
# http://farm1.static.flickr.com/165/422080933_f2b76f9059.jpg
# http://iesmonre.educa.aragon.es/alumnos0405/adaptados/burro.1.gif
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3272/3100217366_346719bdd4.jpg
# http://farm4.static.flickr.com/3018/2568694216_9696c7f542.jpg
# http://www.senderismorioja.com/burro.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm4.static.flickr.com/3196/2721866538_737be3a55c.jpg
# http://www.howellfarm.com/farm/animals/resources/blaze2.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
#
# http://farm2.static.flickr.com/1287/723141955_5eac93e24c.jpg
# http://farm4.static.flickr.com/3276/2547154213_a76f644b7e.jpg
# http://farm4.static.flickr.com/3047/2905376079_0721eb7513.jpg
# http://4.bp.blogspot.com/_zmQ2lE0aFho/SaXZNGrAWSI/AAAAAAAAA1g/xhMLxdncxmc/s400/ELEFANTE++TAILANDES.jpg
# http://farm3.static.flickr.com/2216/2319343874_0ce673301c.jpg
# http://farm4.static.flickr.com/3276/2869156333_23549988cf.jpg
# http://inlinethumb21.webshots.com/9364/1189611966043927185S500x500Q85.jpg
# http://farm4.static.flickr.com/3473/3794033191_0130f020eb.jpg
# http://farm4.static.flickr.com/3035/3024182222_dc1245666f.jpg
# http://farm4.static.flickr.com/3229/2832214657_725c3e25a2.jpg
# http://farm1.static.flickr.com/241/3163044503_206345047f.jpg
# http://farm4.static.flickr.com/3195/3101182385_7208d2205c.jpg
# http://farm4.static.flickr.com/3440/3803793721_c61f756578.jpg
# http://farm4.static.flickr.com/3060/3607460280_a0b404b07b.jpg
# http://farm4.static.flickr.com/3335/3606641893_72971dff85.jpg
# http://farm4.static.flickr.com/3420/3807406651_b9b3a6cb48.jpg
# http://farm4.static.flickr.com/3520/3309028065_ae177d6aab.jpg
# http://farm3.static.flickr.com/2515/3808226408_3db01a26f5.jpg
# http://farm3.static.flickr.com/2461/3825889237_075d88a557.jpg
# http://farm3.static.flickr.com/2471/3803931615_b2b89e70d0.jpg
# http://farm4.static.flickr.com/3662/3607169684_e06047ebc6.jpg
#
# [Errno 2] No such file or directory: ''
#
# [Errno 2] No such file or directory: ''
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-be39b1016314> in <module>()
#      53
#      54 store_raw_images()
# ---> 55 find_uglies()
#      56 create_pos_n_neg()
#      57 # create_pos_raw_image()
#
# <ipython-input-3-be39b1016314> in find_uglies()
#      24     for file_type in ['neg']:
#      25         for img in os.listdir(file_type):
# ---> 26             for ugly in os.listdir('uglies'):
#      27                 try:
#      28                     current_image_path = str(file_type)+'/'+str(img)
#
# OSError: [Errno 2] No such file or directory: 'uglies'

# %%
#find some more background images 
neg_images_link = 'http://image-net.org/api/text/imagenet.synset.geturls?wnid=n07942152'   
neg_image_urls=urllib.urlopen(neg_images_link).read().decode()
pic_num = 292

if not os.path.exists('neg'):
    os.makedirs('neg')

for i in neg_image_urls.split('\n'):
    try:
        if pic_num <=700:
            print(i)

            urllib.urlretrieve(i, "neg/"+str(pic_num)+".jpg")
            img = cv2.imread("neg/"+str(pic_num)+".jpg",cv2.IMREAD_GRAYSCALE)
            # should be larger than samples / pos pic (so we can place our image on it)
            resized_image = cv2.resize(img, (100, 100))
            cv2.imwrite("neg/"+str(pic_num)+".jpg",resized_image)
            pic_num += 1
        else:
            break

    except Exception as e:
        print(str(e))
# Out:
# http://farm4.static.flickr.com/3186/2606823711_b07495378f.jpg
# http://farm4.static.flickr.com/3360/3236502886_6a505502c5.jpg
# http://farm5.static.flickr.com/4022/4322083945_bc2db8ccf3.jpg
# http://farm4.static.flickr.com/3121/2556445732_0f905b11e4.jpg
# http://farm4.static.flickr.com/3551/3443533285_2a70b92f2c.jpg
# http://farm1.static.flickr.com/224/491407069_8dbdc006c4.jpg
# http://farm1.static.flickr.com/33/42539714_c899059d27.jpg
# http://farm4.static.flickr.com/3512/3248952529_0bda5b70eb.jpg
# http://farm3.static.flickr.com/2461/3707202944_74e7a04f77.jpg
# http://farm4.static.flickr.com/3053/2664253302_956cb8356d.jpg
# /Users/jenkins/miniconda/0/2.7/conda-bld/work/opencv-2.4.11/modules/imgproc/src/imgwarp.cpp:1968: error: (-215) ssize.area() > 0 in function resize
# http://farm3.static.flickr.com/2371/2252825594_f54b22a9bc.jpg
# http://farm4.static.flickr.com/3238/3082602410_7ee71285b4.jpg
# http://farm3.static.flickr.com/2461/3706542415_80ce766a7b.jpg
# http://farm3.static.flickr.com/2676/3928462676_a36f861b33.jpg
# http://farm3.static.flickr.com/2578/3822252689_2e32fe1ed0.jpg
# http://farm3.static.flickr.com/2160/2346538808_5bb2d3f077.jpg
# http://farm4.static.flickr.com/3655/3695038709_032877273b.jpg
# http://farm3.static.flickr.com/2059/2260689868_0f87515e77.jpg
# http://farm3.static.flickr.com/2590/3804570268_7967a7ea6c.jpg
# http://farm4.static.flickr.com/3586/3492512150_2df841c7fb.jpg
# http://farm4.static.flickr.com/3053/2492315197_11e4c430f8.jpg
# http://farm3.static.flickr.com/2521/3828070974_c5c47d3713.jpg
# http://farm3.static.flickr.com/2530/3824675231_ab966c6c38.jpg
# http://farm4.static.flickr.com/3163/2861121410_5c4525c9bd.jpg

# %% [markdown]
# Then we will find that there are some white picture and have some text on it. This is because these images are no longer available, instead of serving and HTTP error. We can create a file called 'uglies' and drag one of the "dirty" into this file. Then, we call this find_uglies() method to find all instances of this "dirty" images and remove them.

# %%
#delete "dirty" images      
def find_uglies():
    match = False
    for file_type in ['neg']:
        for img in os.listdir(file_type):
            for ugly in os.listdir('uglies'):
                try:
                    current_image_path = str(file_type)+'/'+str(img)
                    ugly = cv2.imread('uglies/'+str(ugly))
                    question = cv2.imread(current_image_path)
                    if ugly.shape == question.shape and not(np.bitwise_xor(ugly,question).any()):
                        print('That is one ugly pic! Deleting!')
                        print(current_image_path)
                        os.remove(current_image_path)
                except Exception as e:
                    print(str(e))
find_uglies()
# Out:
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/295.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/296.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/297.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/308.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/315.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/316.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/317.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/330.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/331.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/336.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/342.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/343.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/344.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/352.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/360.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/364.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/372.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/376.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/387.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/393.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/397.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/398.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/402.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/406.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/410.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/414.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/418.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/420.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/421.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/424.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/427.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/428.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/440.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/448.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/450.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/457.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/462.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/464.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/473.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/477.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/482.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/486.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/490.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/494.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/499.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/504.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/509.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/512.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/515.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/525.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/535.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/554.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/555.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/560.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/564.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/566.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/567.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/569.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/570.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/575.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/579.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/588.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/590.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/593.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/595.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/601.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/602.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/604.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/613.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/619.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/630.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/633.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/634.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/638.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/642.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/643.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/644.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/650.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/658.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/683.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/684.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/685.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/688.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# That is one ugly pic! Deleting!
# neg/694.jpg
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'
# 'NoneType' object has no attribute 'shape'

# %% [markdown]
# Then we need to create a description txt "bg.txt" for these negative images.

# %%
def create_pos_n_neg():
    for file_type in ['neg']: 
        for img in os.listdir(file_type):
            if file_type == 'neg':
                line = file_type+'/'+img+'\n'
                with open('bg.txt','a') as f:
                    f.write(line)
create_pos_n_neg()

# %%
#create sample image 
apple_img = cv2.imread('apple.jpg')
gray_apple = cv2.cvtColor(apple_img, cv2.COLOR_BGR2GRAY)
resized_img = cv2.resize(gray_apple,(50,50))
cv2.imwrite("sample_apple.jpg",resized_img)

# %% [markdown]
# Here, I used an apple's image and later will detect apples in test image. My experience is crop the image and try best to let the target object fill more space in the whole image. By doing so, we can have a more accurate result.
# <img src="apple.png", height="100" width="100">

# %% [markdown]
# In the following part, we will works on terminal.
# - First, in the terminal window, type "git clone https://github.com/Itseez/opencv.git" to fetch openCV.
# - Second, copy `"createsamples.cpp"` into current working space. We can find `"createsamples.cpp"` in `"/opencv-2.4.13 2/apps/haartraining"`.
# - Third, type `"mkdir info"`. This is the place where we will stuff all of the positive images.
# - Fourth, type `"mkdir data"`. This is the place where we will store all the training output.

# %% [markdown]
# Now, we have done all the preparation works. Now, go ahead and begin training the samples.
# - In the terminal, type `"opencv_createsamples -img sample_apple.jpg -bg bg.txt -info info/info.lst -pngoutput info -maxxangle 0.5 -maxyangle 0.5 -maxzangle 0.5 -num 360 -w 30 -h 30 -vec positives.vec"`
# - Using this You can find command line arguments' meaning here: [http://docs.opencv.org/3.1.0/dc/d88/tutorial_traincascade.html](http://docs.opencv.org/3.1.0/dc/d88/tutorial_traincascade.html)

# %% [markdown]
# Sample output:
# <img src="terminal_1.png", height="500" width="800">

# %% [markdown]
# So far,we have already create sample images and a positive vector. Now,we can start the training process. To do the training, in the terminal, type  `"opencv_traincascade -data data -vec positives.vec -bg bg.txt -numPos 300 -numNeg 150 -numStages 10 -w 30 -h 30"`

# %% [markdown]
# Sample output:
# <img src="terminal_2.png", height="500" width="800">

# %% [markdown]
# Then, in our "data" file, we can find `cascade.xml`. That is the our own "Haar Cascade classifier". Now, we can go ahead to the detection stage.

# %%
# import our own cascade.xml, here I renamed it to "apple_cascade.xml"
apple_cascade=cv2.CascadeClassifier('apple_cascade.xml')

apple_img = cv2.imread('apple_target1.jpg')
gray = cv2.cvtColor(apple_img, cv2.COLOR_BGR2GRAY)
apple = apple_cascade.detectMultiScale(gray, 1.1,3)
for (x,y,w,h) in apple:
    cv2.rectangle(apple_img,(x,y),(x+w,y+h),(255,255,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = apple_img[y:y+h, x:x+w]
cv2.imshow('img',apple_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# Sample output:
# <img src="output.png", height="100" width="200">

# %% [markdown]
# We can see the output is not that accurate. We can increase the accuracy by adding more background image, or more positive images. Also, we can change the command line arguments's value. For example, we use "-w 30 -h 30", we can increase these numbers and it will be more expensive. Also, we can change "-numPos 300 -numNeg 150".

# %% [markdown]
# ## Useful Links

# %% [markdown]
# Resource for Haar Cascades:
# - http://www.bogotobogo.com/python/OpenCV_Python/python_opencv3_Image_Object_Detection_Face_Detection_Haar_Cascade_Classifiers.php
# - http://www.cognotics.com/opencv/servo_2007_series/part_2/sidebar.html
# - http://docs.opencv.org/3.1.0/dc/d88/tutorial_traincascade.html
# - https://pythonprogramming.net/haar-cascade-object-detection-python-opencv-tutorial/

# %% [markdown]
# Resource for openCV library
# - [http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html](http://docs.opencv.org/3.0-beta/doc/py_tutorials/py_tutorials.html)

# %% [markdown]
# #### Hope you enjoy this tutorial. Cheers!
