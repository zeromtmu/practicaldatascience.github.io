# %% [markdown]
# [Scrapy](https://scrapy.org/) is an application framework for crawling web sites and extracting structured data. It is a powerful tool in the fields of Data Collection, Data Processing and Data Mining.

# %% [markdown]
# ## Installing Scrapy
#
# Installing Scrapy requires dependencies of Python 2.7 or above. There are three common options to install Scrapy. If you don't have Scrapy installed on your machine, it is advised to use the first option to install.
# 1) You can use [Anaconda](https://www.continuum.io/) to install (recommended option):

# %%
# !conda install -c scrapinghub scrapy
# Out:
# Fetching package metadata .........
# Solving package specifications: ..........
#
# # All requested packages already installed.
# # packages in environment at /Users/apple/anaconda2:
# #
# scrapy                    1.2.0                    py27_0    scrapinghub

# %% [markdown]
# 2) You can also install Scrapy and its dependencies with [pip](https://pypi.python.org/pypi/pip):
# `pip install Scrapy`
#
# 3) You can also use [virtualenv](https://virtualenv.pypa.io/en/stable/installation/) to install Scrapy so that you may avoid possible conflicts with your system packages.

# %% [markdown]
# ## A skim through Scrapy
# After the installation of Scrapy, let's get started to work with Scrapy!
#
# ### Create a project
# The first step is to creat a new Scrapy project, there are a couple of things to note when you configure the Scrapy project.

# %%
# !rm -rf demo || true
# !scrapy startproject demo
# Out:
# New Scrapy project 'demo', using template directory '/Users/apple/anaconda2/lib/python2.7/site-packages/scrapy/templates/project', created in:
#     /Users/apple/Desktop/PDS/tutorial/demo
#
# You can start your first spider with:
#     cd demo
#     scrapy genspider example example.com

# %% [markdown]
# The command above will get you a directory named firstscrapyproject with following structures:
#
# ```
# demo
# ├── demo
# │   ├── __init__.py
# │   ├── items.py
# │   ├── pipelines.py
# │   ├── settings.py
# │   └── spiders
# │       └── __init__.py
# └── scrapy.cfg
# ```
# ### Create an infant spider
# The "spider" is the class that we use to define the actions that how to parse the extracted pages after making the requests. It must extend the scrapy.Spider class and stored under the `firstscrapyproject/spiders` directory.
#
# Below is a simple example showing how to create a spider, for example if we want take a look at recent updates regarding Google products, we could just sent request to crawl the Google products update on Google blog, and we would keep all the cnntents of that page to `Google-products.html` for simplicity. This is just an simple example to introduce spider.

# %%
import scrapy

class SimpleSpider(scrapy.Spider):
    name = "simplespider" # name must be unique within project.
    
    def start_requests(self):
        urls = [
            'https://blog.google/products/',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            
    def parse(self, response):
        category = response.url.split('/')[-2]
        file_name = 'Google-%s.html' % category
        with open(file_name, 'wb') as f:
            f.write(response.body) # simply record all the contents of page
        self.log('%s is saved.' % file_name)

# %% [markdown]
# For reader's convenience, we have already put code above in a python file `SimpleSpider.py`, so simply run the shell commands below to move it to where it should be put in the project folder.

# %%
# %cp SimpleSpider.py demo/demo/spiders

# %% [markdown]
# ### Run a spider
# After creating the spider, we will need it to work using following command, be sure to be aware that you need to get into the project folder instead of staying in current directory, after we run the spider, a good strategy is that we get back to the previous directory so that we will not get lost.

# %%
# %cd demo
# !scrapy crawl simplespider
# !cat Google-products.html | head -n 100 # show top 100 lines of extracted html page
# %cd -
# Out:
# /Users/apple/Desktop/PDS/tutorial/demo
# 2016-11-02 02:18:59 [scrapy] INFO: Scrapy 1.2.0 started (bot: demo)
# 2016-11-02 02:18:59 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'demo.spiders', 'SPIDER_MODULES': ['demo.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'demo'}
# 2016-11-02 02:18:59 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 02:18:59 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 02:18:59 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 02:18:59 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 02:18:59 [scrapy] INFO: Spider opened
# 2016-11-02 02:18:59 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 02:18:59 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-02 02:18:59 [scrapy] DEBUG: Crawled (200) <GET https://blog.google/robots.txt> (referer: None)
# 2016-11-02 02:18:59 [scrapy] DEBUG: Crawled (200) <GET https://blog.google/products/> (referer: None)
# 2016-11-02 02:19:00 [simplespider] DEBUG: Google-products.html is saved.
# 2016-11-02 02:19:00 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 02:19:00 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 437,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 44307,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 6, 19, 0, 52991),
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 2, 6, 18, 59, 539189)}
# 2016-11-02 02:19:00 [scrapy] INFO: Spider closed (finished)
#
#
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <!--<![endif]-->
#
#     <head>
#         <meta charset="utf-8" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <title>Products | The Keyword</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1" />
#
#
#
#
#
#
#
# <!--Article Specific Metadata-->
# <meta name="description" content="Dive deep into the latest news about products across Google."/>
#
# <!--Open Graph Metadata-->
# <meta property="og:type" content="website" />
# <meta property="og:title" content="Products"/>
# <meta property="og:description" content="Dive deep into the latest news about products across Google." />
# <meta property="og:image" content="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google-200x200.7714256da16f.png" />
# <meta property="og:site_name" content="www.blog.google" />
# <meta property="og:url" content="https://blog.google/products/" />
#
# <!--Twitter Card Metadata-->
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:url" content="https://blog.google/products/" />
# <meta name="twitter:title" content="Products"/>
# <meta name="twitter:description" content="Dive deep into the latest news about products across Google." />
# <meta name="twitter:image:src" content="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google-200x200.7714256da16f.png" />
# <meta name="twitter:site" content="@google" />
#
#
#
#         <link rel="stylesheet" type="text/css" href="/static/blog/css/blog.min.css" />
#         <link href="//fonts.googleapis.com/css?family=Roboto:100,200,300,400,500,700" rel="stylesheet">
#         <link href="//fonts.googleapis.com/css?family=Roboto+Slab:100,200,300,400" rel="stylesheet">
#         <link rel="stylesheet" type="text/css" href="/static/blog/css/print.min.css" media="print" />
#
#
#
#
#     </head>
#
#     <body class="template-productsnavigationpage" uni-component="externalLinks">
#
#
#
# <div data-layer="
#     {
#
#             'slug': 'products',
#
#
#             'contentType': 'products navigation page',
#
#
#
#
#
#
#
#
#
#
#
#
#     }"></div>
#
# <script type="text/javascript" src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/js/data-layer-analytics.da7f878b7c0e.js"></script>
#
#
#
# <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-TRV24V"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script type="text/javascript" src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/js/gtm.d797bb14a102.js"></script>
#
#
#
#
#
# <a class="uni-header-skip-menu" tabindex="0" uni-component="skipMenu">
#     Skip to Main Content
# </a>
#
# <header class="uni-header-content" uni-component="header">
#     <div class="uni-header-wrapper">
#         <div class="uni-header-row uni-google-logo">
#             <a href="/">
#                 <figure>
#                     <img src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google.a51985becaa6.png" alt=" Google">
# /Users/apple/Desktop/PDS/tutorial

# %% [markdown]
# ### Simplify a spider class
# Actually, there's a way that can spare our efforts to implement `start_requests()` method, instead we need to define a `start_urls` class attribute which is a list of URLs. We can do this because `parse()` is Scrapy's default callback method.

# %%
import scrapy

class SimplifiedSimpleSpider(scrapy.Spider):
    name = "simplifiedsimplespider" # name must be unique within project.
    
    # remove start_requests(), use start_urls instead
    start_urls = [
        'https://blog.google/topics/',
    ]
            
    def parse(self, response):
        category = response.url.split('/')[-2]
        file_name = 'Google-simplified-%s.html' % category
        with open(file_name, 'wb') as f:
            f.write(response.body)
        self.log('%s is saved.' % file_name)

# %%
# %cp SimplifiedSimpleSpider.py demo/demo/spiders
# %cd demo
# !scrapy crawl simplifiedsimplespider
# !cat Google-simplified-topics.html | head -n 100 # show top 100 lines of extracted html page
# %cd -
# Out:
# /Users/apple/Desktop/PDS/tutorial/demo
# 2016-11-02 02:19:01 [scrapy] INFO: Scrapy 1.2.0 started (bot: demo)
# 2016-11-02 02:19:01 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'demo.spiders', 'SPIDER_MODULES': ['demo.spiders'], 'ROBOTSTXT_OBEY': True, 'BOT_NAME': 'demo'}
# 2016-11-02 02:19:01 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 02:19:01 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 02:19:01 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 02:19:01 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 02:19:01 [scrapy] INFO: Spider opened
# 2016-11-02 02:19:01 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 02:19:01 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-02 02:19:01 [scrapy] DEBUG: Crawled (200) <GET https://blog.google/robots.txt> (referer: None)
# 2016-11-02 02:19:01 [scrapy] DEBUG: Crawled (200) <GET https://blog.google/topics/> (referer: None)
# 2016-11-02 02:19:01 [simplifiedsimplespider] DEBUG: Google-simplified-topics.html is saved.
# 2016-11-02 02:19:01 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 02:19:01 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 435,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 30686,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 6, 19, 1, 777988),
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 7,
#  'response_received_count': 2,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 2, 6, 19, 1, 318064)}
# 2016-11-02 02:19:01 [scrapy] INFO: Spider closed (finished)
#
#
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" xmlns='http://www.w3.org/1999/xhtml' xml:lang='en' lang='en' > <!--<![endif]-->
#
#     <head>
#         <meta charset="utf-8" />
#         <meta http-equiv="X-UA-Compatible" content="IE=edge" />
#         <title>Topics | The Keyword</title>
#         <meta name="viewport" content="width=device-width, initial-scale=1" />
#
#
#
#
#
#
#
# <!--Article Specific Metadata-->
# <meta name="description" content="Explore all our site&#39;s themes and topics as seen through the Google lens."/>
#
# <!--Open Graph Metadata-->
# <meta property="og:type" content="website" />
# <meta property="og:title" content="Topics"/>
# <meta property="og:description" content="Explore all our site&#39;s themes and topics as seen through the Google lens." />
# <meta property="og:image" content="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google-200x200.7714256da16f.png" />
# <meta property="og:site_name" content="www.blog.google" />
# <meta property="og:url" content="https://blog.google/topics/" />
#
# <!--Twitter Card Metadata-->
# <meta name="twitter:card" content="summary" />
# <meta name="twitter:url" content="https://blog.google/topics/" />
# <meta name="twitter:title" content="Topics"/>
# <meta name="twitter:description" content="Explore all our site&#39;s themes and topics as seen through the Google lens." />
# <meta name="twitter:image:src" content="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google-200x200.7714256da16f.png" />
# <meta name="twitter:site" content="@google" />
#
#
#
#         <link rel="stylesheet" type="text/css" href="/static/blog/css/blog.min.css" />
#         <link href="//fonts.googleapis.com/css?family=Roboto:100,200,300,400,500,700" rel="stylesheet">
#         <link href="//fonts.googleapis.com/css?family=Roboto+Slab:100,200,300,400" rel="stylesheet">
#         <link rel="stylesheet" type="text/css" href="/static/blog/css/print.min.css" media="print" />
#
#
#
#
#     </head>
#
#     <body class="template-topicsnavigationpage" uni-component="externalLinks">
#
#
#
# <div data-layer="
#     {
#
#             'slug': 'topics',
#
#
#             'contentType': 'topics navigation page',
#
#
#
#
#
#
#
#
#
#
#
#
#     }"></div>
#
# <script type="text/javascript" src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/js/data-layer-analytics.da7f878b7c0e.js"></script>
#
#
#
# <!-- Google Tag Manager -->
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-TRV24V"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <script type="text/javascript" src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/js/gtm.d797bb14a102.js"></script>
#
#
#
#
#
# <a class="uni-header-skip-menu" tabindex="0" uni-component="skipMenu">
#     Skip to Main Content
# </a>
#
# <header class="uni-header-content" uni-component="header">
#     <div class="uni-header-wrapper">
#         <div class="uni-header-row uni-google-logo">
#             <a href="/">
#                 <figure>
#                     <img src="https://storage.googleapis.com/gweb-uniblog-publish-prod/static/blog/images/google.a51985becaa6.png" alt=" Google">
# /Users/apple/Desktop/PDS/tutorial

# %% [markdown]
# ### Use spider to do something more complicated
# Until now, we just define our "spider" to fetch the whole page for us, however we have not done anything specific to the pages we just retrieved. So you may want to add some interesting actions on the spider, let's get started from modifying the `parse(response)` method.
# In the example below, we will try to crawl the website of National Park Service where we can get comprehensive information about all the national parks in United States. Now we want all the names of national parks located in Alaska(AK) and California(CA). We first sent request to the pages containing information about national parks in Alaska and California, after that we will analyze the structure of those two pages and use simple css selector to extract the information we want.

# %%
import scrapy

class FindParkSpider(scrapy.Spider):
    name = "findparkspider"
    
    states = ['ca']
    start_urls = [
        'https://www.nps.gov/state/ak/index.htm',
        'https://www.nps.gov/state/ca/index.htm',
    ]

    def parse(self, response):
        for r in response.css('div#parkListResultsArea'):
            yield {
                'park_name': r.css('h3 a::text').extract(),
                'park_description': r.css('div.list_left p::text').extract(),
            }

# %% [markdown]
# After extracting the information that we are interested in, we need to store them by using following command in json format:

# %%
# %cp FindParkSpider.py demo/demo/spiders
# %cd demo
# !scrapy crawl findparkspider -o parks-ak-ca.json
# %cat parks-ak-ca.json | head -n 100 # show top 100 lines of extracted json file
# %cd -
# Out:
# /Users/apple/Desktop/PDS/tutorial/demo
# 2016-11-02 02:19:03 [scrapy] INFO: Scrapy 1.2.0 started (bot: demo)
# 2016-11-02 02:19:03 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'demo.spiders', 'FEED_URI': 'parks-ak-ca.json', 'SPIDER_MODULES': ['demo.spiders'], 'BOT_NAME': 'demo', 'ROBOTSTXT_OBEY': True, 'FEED_FORMAT': 'json'}
# 2016-11-02 02:19:03 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 02:19:03 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 02:19:03 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 02:19:03 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 02:19:03 [scrapy] INFO: Spider opened
# 2016-11-02 02:19:03 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 02:19:03 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-02 02:19:03 [scrapy] DEBUG: Crawled (200) <GET https://www.nps.gov/robots.txt> (referer: None)
# 2016-11-02 02:19:03 [scrapy] DEBUG: Crawled (200) <GET https://www.nps.gov/state/ak/index.htm> (referer: None)
# 2016-11-02 02:19:03 [scrapy] DEBUG: Crawled (200) <GET https://www.nps.gov/state/ca/index.htm> (referer: None)
# 2016-11-02 02:19:03 [scrapy] DEBUG: Scraped from <200 https://www.nps.gov/state/ak/index.htm>
# {'park_description': [u'\nThe headwaters of Alagnak Wild River lie within the rugged Aleutian Range of neighboring Katmai National Park and Preserve. Meandering west towards Bristol Bay and the Bering Sea, the Alagnak traverses the beautiful Alaska Peninsula, providing an unparalleled opportunity to experience the unique wilderness, wildlife, and cultural heritage of southwest Alaska.\n', u'\nAlaska\u2019s parks, forests and refuges are rich and varied. The Anchorage Interagency Visitor Center helps visitors and residents to have meaningful, safe, enjoyable experiences on public lands, and encourages them to sustain the natural and cultural resources of Alaska. This center and three others statewide provide trip-planning, interpretation, and education for all ages.\n', u'\nDuring World War II the remote Aleutian Islands, home to the Unangan (Aleut) people for over 8,000 years, became a fiercely contested battleground in the Pacific. This thousand-mile-long archipelago saw invasion by Japanese forces, the occupation of two islands; a mass relocation of Unangax civilians; a 15-month air war; and one of the deadliest battles in the Pacific Theater.\n', u'\nGiven its remote location and challenging weather conditions, Aniakchak is one of the most wild and least visited in places in the National Park System. This landscape is a vibrant reminder of Alaska\'s location in the volcanically active "Ring of Fire" as it is home to an impressive six mile (10 km) wide, 2,500 ft (762 m) deep caldera formed during a massive volcanic eruption 3,500 years ago.\n', u'\nImagine a place of whimsical beauty and larger-than-life landscapes: an ancestral home to ice-age giants and turbulent volcanic activity. A land that holds secrets to the intriguing history of human migration, sustains people that have lived here before its establishment as a preserve and continues to be part of a wide breadth of? traditions. Bering Land Bridge is unlike any other place on earth.\n', u'\nNorth of the Arctic Circle, the monument forms 70 miles of shoreline on the Chukchi Sea.  More than 114 beach ridges provide evidence of human use for 5,000 years.  The Inupiat continue to use the area today.  Vast wetlands provide habitat for shorebirds from as far away as South America.  Hikers and boaters can see carpets of wildflowers among shrubs containing wisps of qiviut from muskoxen.\n', u"\nDenali is six million acres of wild land, bisected by one ribbon of road. Travelers along it see the relatively low-elevation taiga forest give way to high alpine tundra and snowy mountains, culminating in North America's tallest peak, 20,310' Denali. Wild animals large and small roam un-fenced lands, living as they have for ages. Solitude, tranquility and wilderness await.\n", u'\nThis vast landscape does not contain any roads or trails. Visitors discover intact ecosystems where people have lived with the land for thousands of years. Wild rivers meander through glacier-carved valleys, caribou migrate along age-old trails, endless summer light fades into aurora-lit night skies of winter. It remains virtually unchanged except by the forces of nature.\n', u"\nCovering 3.3 million acres of rugged mountains, dynamic glaciers, temperate rainforest, wild coastlines and deep sheltered fjords, Glacier Bay National Park is a highlight of Alaska's Inside Passage and part of a 25-million acre World Heritage Site\u2014one of the world\u2019s largest international protected areas. From sea to summit, Glacier Bay offers limitless opportunities for adventure and inspiration.\n", u'\nOn the rooftop of the world, the I\xf1upiat Heritage Center in Barrow, Alaska, tells the story of the I\xf1upiat people. They have thrived for thousands of years in one of the harshest climates on Earth, hunting the bowhead, or "Agviq." In the 19th century, these lonely seas swarmed with commercial whalemen from New England, who also sought the bowhead for its valuable baleen and blubber.\n', u'\nKatmai National Monument ...
# 2016-11-02 02:19:04 [scrapy] DEBUG: Scraped from <200 https://www.nps.gov/state/ca/index.htm>
# {'park_description': [u'\nAlcatraz Island offers a close-up look at the site of the first lighthouse and US built fort on the West Coast, the infamous federal penitentiary long off-limits to the public, and the history making 18 month occupation by Indians of All Tribes. Rich in history, there is also a natural side to the Rock\u2014gardens, tide pools, bird colonies, and bay views beyond compare.\n', u'\nClimbing out of his boat and onto shore in 1542, Juan Rodriguez Cabrillo stepped into history as the first European to set foot on what is now the West Coast of the United States. In addition to telling the story of 16th century exploration, the park is home to a wealth of cultural and natural resources. Join us and embark on your own Voyage of Discovery.\n', u'\nFollow in the footsteps of over 250,000 emigrants who traveled to the gold fields and rich farmlands of California during the 1840s and 1850s-the greatest mass migration in American history. More than 1,000 miles of trail ruts and traces can still be seen across 10 states on the California National Historic Trail.\n', u'\nCastle Mountains represents some of the most unique elements of the Mojave Desert. Nestled between the Nevada state line and Mojave National Preserve, the nearly 21,000 acres of Castle Mountains boasts Joshua tree forests, unbroken natural landscapes, rare desert grasslands, and rich human history. This intriguing area provides serenity and solitude from nearby metropolitan areas.\n', u"\nYes, we can!\nWidely recognized as the most important Latino leader in the United States during the twentieth century, C\xe9sar E. Ch\xe1vez led farm workers and supporters in the establishment of the country's first permanent agricultural union. His leadership brought sustained international attention to the plight of U.S. farm workers, and secured for them higher wages and safer working conditions\n", u'\nChannel Islands National Park encompasses five remarkable islands and their ocean environment, preserving and protecting a wealth of natural and cultural resources. Isolation over thousands of years has created unique animals, plants, and archeological resources found nowhere else on Earth and helped preserve a place where visitors can experience coastal southern California as it once was.\n', u'\nIn this below-sea-level basin, steady drought and record summer heat make Death Valley a land of extremes. Yet, each extreme has a striking contrast. Towering peaks are frosted with winter snow. Rare rainstorms bring vast fields of wildflowers. Lush oases harbor tiny fish and refuge for wildlife and humans. Despite its morbid name, a great diversity of life survives in Death Valley.\n', u"\nEstablished in 1911 by presidential proclamation, Devils Postpile National Monument protects and preserves the Devils Postpile formation, the 101-foot high Rainbow Falls, and pristine mountain scenery.  The formation is a rare sight in the geologic world and ranks as one of the world's finest examples of columnar basalt. Its columns tower 60 feet high and display an unusual symmetry.\n", u"\nAmerica's only Nobel Prize winning playwright, Eugene O'Neill, chose to live in Northern California at the height of his writing career. Isolated from the world and within the walls of his home, O'Neill wrote his final and most memorable plays; The Iceman Cometh, Long Day's Journey Into Night, and A Moon for the Misbegotten.\n", u"\nFrom its vantage point overlooking the spectacular Golden Gate, Fort Point defended the San Francisco Bay following California's Gold Rush through World War II. Its beautifully arched casemates display the art of 3rd system brick masonry and interacts gracefully with the Golden Gate Bridge.\n", u'\nThe park chronicles 200 years of history from Native American culture, Spanish Empire frontier, the Gold Rush, evolution of American coastal fortifications and growth of urban San Francisco. Comprised of 19 separate ecosystems and home to 1,273 plant/animal species, the pa ...
# 2016-11-02 02:19:04 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 02:19:04 [scrapy] INFO: Stored json feed (2 items) in: parks-ak-ca.json
# 2016-11-02 02:19:04 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 673,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 34111,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 3,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 6, 19, 4, 25516),
#  'item_scraped_count': 2,
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 8,
#  'response_received_count': 3,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2016, 11, 2, 6, 19, 3, 666017)}
# 2016-11-02 02:19:04 [scrapy] INFO: Spider closed (finished)
# [
# {"park_name": ["Alagnak", "Alaska Public Lands", "Aleutian World War II", "Aniakchak", "Bering Land Bridge", "Cape Krusenstern", "Denali", "Gates Of The Arctic", "Glacier Bay", "I\u00f1upiat Heritage Center", "Katmai", "Kenai Fjords", "Klondike Gold Rush", "Kobuk Valley", "Lake Clark", "Noatak", "Sitka", "World War II Valor in the Pacific", "Wrangell - St Elias", "Yukon - Charley Rivers"], "park_description": ["\nThe headwaters of Alagnak Wild River lie within the rugged Aleutian Range of neighboring Katmai National Park and Preserve. Meandering west towards Bristol Bay and the Bering Sea, the Alagnak traverses the beautiful Alaska Peninsula, providing an unparalleled opportunity to experience the unique wilderness, wildlife, and cultural heritage of southwest Alaska.\n", "\nAlaska\u2019s parks, forests and refuges are rich and varied. The Anchorage Interagency Visitor Center helps visitors and residents to have meaningful, safe, enjoyable experiences on public lands, and encourages them to sustain the natural and cultural resources of Alaska. This center and three others statewide provide trip-planning, interpretation, and education for all ages.\n", "\nDuring World War II the remote Aleutian Islands, home to the Unangan (Aleut) people for over 8,000 years, became a fiercely contested battleground in the Pacific. This thousand-mile-long archipelago saw invasion by Japanese forces, the occupation of two islands; a mass relocation of Unangax civilians; a 15-month air war; and one of the deadliest battles in the Pacific Theater.\n", "\nGiven its remote location and challenging weather conditions, Aniakchak is one of the most wild and least visited in places in the National Park System. This landscape is a vibrant reminder of Alaska's location in the volcanically active \"Ring of Fire\" as it is home to an impressive six mile (10 km) wide, 2,500 ft (762 m) deep caldera formed during a massive volcanic eruption 3,500 years ago.\n", "\nImagine a place of whimsical beauty and larger-than-life landscapes: an ancestral home to ice-age giants and turbulent volcanic activity. A land that holds secrets to the intriguing history of human migration, sustains people that have lived here before its establishment as a preserve and continues to be part of a wide breadth of? traditions. Bering Land Bridge is unlike any other place on earth.\n", "\nNorth of the Arctic Circle, the monument forms 70 miles of shoreline on the Chukchi Sea.  More than 114 beach ridges provide evidence of human use for 5,000 years.  The Inupiat continue to use the area today.  Vast wetlands provide habitat for shorebirds from as far away as South America.  Hikers and boaters can see carpets of wildflowers among shrubs containing wisps of qiviut from muskoxen.\n", "\nDenali is six million acres of wild land, bisected by one ribbon of road. Travelers along it see the relatively low-elevation taiga forest give way to high alpine tundra and snowy mountains, culminating in North America's tallest peak, 20,310' Denali. Wild animals large and small roam un-fenced lands, living as they have for ages. Solitude, tranquility and wilderness await.\n", "\nThis vast landscape does not contain any roads or trails. Visitors discover intact ecosystems where people have lived with the land for thousands of years. Wild rivers meander through glacier-carved valleys, caribou migrate along age-old trails, endless summer light fades into aurora-lit night skies of winter. It remains virtually unchanged except by the forces of nature.\n", "\nCovering 3.3 million acres of rugged mountains, dynamic glaciers, temperate rainforest, wild coastlines and deep sheltered fjords, Glacier Bay National Park is a highlight of Alaska's Inside Passage and part of a 25-million acre World Heritage Site\u2014one of the world\u2019s largest international protected areas. From sea to summit, Glacier Bay offers limitless opportunities for adventure and inspiration.\n", "\nOn the rooftop of the world, the I\u00f1u ...
# {"park_name": ["Alcatraz Island", "Cabrillo", "California", "Castle Mountains", "C\u00e9sar E. Ch\u00e1vez", "Channel Islands", "Death Valley", "Devils Postpile", "Eugene O'Neill", "Fort Point", "Golden Gate", "John Muir", "Joshua Tree", "Juan Bautista de Anza", "Lassen Volcanic", "Lava Beds", "Manzanar", "Mojave", "Muir Woods", "Old Spanish", "Pinnacles", "Point Reyes", "Pony Express", "Port Chicago Naval Magazine", "Presidio of San Francisco", "Redwood", "Rosie the Riveter WWII Home Front", "San Francisco Maritime", "Santa Monica Mountains", "Sequoia & Kings Canyon", "Tule Lake Unit", "Whiskeytown", "World War II Valor in the Pacific", "Yosemite"], "park_description": ["\nAlcatraz Island offers a close-up look at the site of the first lighthouse and US built fort on the West Coast, the infamous federal penitentiary long off-limits to the public, and the history making 18 month occupation by Indians of All Tribes. Rich in history, there is also a natural side to the Rock\u2014gardens, tide pools, bird colonies, and bay views beyond compare.\n", "\nClimbing out of his boat and onto shore in 1542, Juan Rodriguez Cabrillo stepped into history as the first European to set foot on what is now the West Coast of the United States. In addition to telling the story of 16th century exploration, the park is home to a wealth of cultural and natural resources. Join us and embark on your own Voyage of Discovery.\n", "\nFollow in the footsteps of over 250,000 emigrants who traveled to the gold fields and rich farmlands of California during the 1840s and 1850s-the greatest mass migration in American history. More than 1,000 miles of trail ruts and traces can still be seen across 10 states on the California National Historic Trail.\n", "\nCastle Mountains represents some of the most unique elements of the Mojave Desert. Nestled between the Nevada state line and Mojave National Preserve, the nearly 21,000 acres of Castle Mountains boasts Joshua tree forests, unbroken natural landscapes, rare desert grasslands, and rich human history. This intriguing area provides serenity and solitude from nearby metropolitan areas.\n", "\nYes, we can!\nWidely recognized as the most important Latino leader in the United States during the twentieth century, C\u00e9sar E. Ch\u00e1vez led farm workers and supporters in the establishment of the country's first permanent agricultural union. His leadership brought sustained international attention to the plight of U.S. farm workers, and secured for them higher wages and safer working conditions\n", "\nChannel Islands National Park encompasses five remarkable islands and their ocean environment, preserving and protecting a wealth of natural and cultural resources. Isolation over thousands of years has created unique animals, plants, and archeological resources found nowhere else on Earth and helped preserve a place where visitors can experience coastal southern California as it once was.\n", "\nIn this below-sea-level basin, steady drought and record summer heat make Death Valley a land of extremes. Yet, each extreme has a striking contrast. Towering peaks are frosted with winter snow. Rare rainstorms bring vast fields of wildflowers. Lush oases harbor tiny fish and refuge for wildlife and humans. Despite its morbid name, a great diversity of life survives in Death Valley.\n", "\nEstablished in 1911 by presidential proclamation, Devils Postpile National Monument protects and preserves the Devils Postpile formation, the 101-foot high Rainbow Falls, and pristine mountain scenery.  The formation is a rare sight in the geologic world and ranks as one of the world's finest examples of columnar basalt. Its columns tower 60 feet high and display an unusual symmetry.\n", "\nAmerica's only Nobel Prize winning playwright, Eugene O'Neill, chose to live in Northern California at the height of his writing career. Isolated from the world and within the walls of his home, O'Neill wrote his final and most memorable plays; The Iceman ...
# ]/Users/apple/Desktop/PDS/tutorial

# %% [markdown]
# By appending -o parameter after the command, we will get an output file `output.json` which contains all scraped data in JSON format.

# %% [markdown]
# ### Extend the feet of spider to "next" page
# In most cases, you will not be satisfied if you just extract one or two pages, so if there is a link to the next page, you may find it to be very helpful, the spider will love it!
# In the following example, we are going to send our spider to Yelp to find which restaurants are popular in Pittsburgh. We simply ask the spider to work on the page which holds the information of those popular restaurants with rank from high to low. We will extract the names, average ratings and review counts of listed restaurants. Obviously, one page is not enough to hold so many great popular restaurants in Pittsbugh, what can we do to find them all? No worry, we can take advantage of the "next" anchor in the end of each page. Let's see how spider find there next destination through example below. **It is worth noting that when you crawl some websites, you may encounter a problem related to robot settings, to solve this, simply make some slight modification in project directory (in this case `demo/demo/settings.py`) by setting ROBOTSTXT_OBEY = False from default True. Please also note these process could take at most 3 minutes since there are so many next pages.**

# %%
import scrapy

class YelpSpider(scrapy.Spider):
    name = "yelpspider"
    
    start_urls = [
        'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0',
    ]

    def parse(self, response):
        for r in response.css('ul.ylist.ylist-bordered.search-results'):
            yield {
                'restaurant_name': r.css('span.indexed-biz-name a.biz-name.js-analytics-click span::text').extract(),
                'rating': [float(x.split(' ')[0]) for x in r.css('div.rating-large i.star-img::attr(title)').extract()],
                'review_count': [int(x.strip().split(' ')[0]) for x in r.css('span.review-count::text').extract()],
            }
        next_page = response.css('a.u-decoration-none.next.pagination-links_anchor::attr(href)').extract_first()
        if next_page is not None:
            next_page = response.urljoin(next_page)
            yield scrapy.Request(next_page, callback=self.parse)

# %%
# %cp YelpSpider.py demo/demo/spiders
# %cd demo
# !scrapy crawl yelpspider -o yelp-pittsburgh-restaurant.json
# !cat yelp-pittsburgh-restaurant.json | head -n 100 # show top 100 lines of extracted json file
# %cd -
# Out:
# /Users/apple/Desktop/PDS/tutorial/demo
# 2016-11-02 12:45:46 [scrapy] INFO: Scrapy 1.2.0 started (bot: demo)
# 2016-11-02 12:45:46 [scrapy] INFO: Overridden settings: {'NEWSPIDER_MODULE': 'demo.spiders', 'FEED_FORMAT': 'json', 'SPIDER_MODULES': ['demo.spiders'], 'FEED_URI': 'yelp-pittsburgh-restaurant.json', 'BOT_NAME': 'demo'}
# 2016-11-02 12:45:46 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.feedexport.FeedExporter',
#  'scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 12:45:46 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 12:45:46 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 12:45:46 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 12:45:46 [scrapy] INFO: Spider opened
# 2016-11-02 12:45:46 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 12:45:46 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6025
# 2016-11-02 12:45:49 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0> (referer: None)
# 2016-11-02 12:45:49 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:45:49 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0>
# {'review': [4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5, 4.5], 'review_counts': [994, 448, 142, 508, 274, 54, 79, 298, 144, 126], 'restaurant_name': [u'Gaucho Parrilla Argentina', u't\xe4k\u014d', u'Las Palmas', u'Butcher and the Rye', u'Altius', u'Umbrella Cafe', u'The Twisted Frenchman', u'Legume', u'Smallman Galley', u'Doce Taqueria']}
# 2016-11-02 12:45:51 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=10> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0)
# 2016-11-02 12:45:51 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=10>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:45:51 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=10>
# {'review': [4.0, 4.0, 4.5, 5.0, 4.0, 4.0, 4.5, 4.5, 4.5, 4.5], 'review_counts': [1255, 492, 587, 49, 226, 324, 191, 177, 479, 69], 'restaurant_name': [u'Meat & Potatoes', u'Eleven', u'Noodlehead', u'Cop Out Pierogies', u'Penn Ave Fish Company', u'Cure', u'Bakersfield Penn Ave', u'Las Palmas Carniceria', u'Point Brugge Caf\xe9', u'B52 Cafe']}
# 2016-11-02 12:45:57 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=20> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=10)
# 2016-11-02 12:45:57 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=20>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:45:57 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=20>
# {'review': [4.5, 4.5, 4.0, 4.5, 4.5, 4.5, 4.5, 4.0, 5.0, 4.0], 'review_counts': [62, 123, 348, 112, 84, 161, 136, 139, 40, 572], 'restaurant_name': [u'Apteka', u'Alla Famiglia', u'Proper Brick Oven & Tap Room', u'Morcilla', u'Peppi\u2019s', u'The Pub Chip Shop', u'Cafe Du Jour', u'Butterjoint', u'Edgar Tacos Stand', u'Fat Heads Saloon']}
# 2016-11-02 12:46:01 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=30> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=20)
# 2016-11-02 12:46:01 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=30>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:01 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=30>
# {'review': [4.5, 4.0, 4.5, 4.5, 4.0, 4.0, 4.0, 4.5, 4.0, 4.0], 'review_counts': [208, 358, 79, 125, 468, 107, 106, 50, 223, 282], 'restaurant_name': [u'Istanbul Sofra', u'Nicky\u2019s Thai Kitchen', u'Amazing Cafe', u'La Palapa, Mexican Gourmet Kitchen', u'Kaya', u'Burgatory', u'The Smiling Moose', u'Streets On Carson', u'Park Bruges', u'Monterey Bay Fish Grotto']}
# 2016-11-02 12:46:03 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=40> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=30)
# 2016-11-02 12:46:03 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=40>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:03 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=40>
# {'review': [4.5, 4.0, 4.0, 5.0, 4.0, 4.0, 4.0, 5.0, 4.0, 4.0], 'review_counts': [97, 395, 113, 17, 127, 356, 284, 40, 492, 391], 'restaurant_name': [u'Alihan\u2019s Mediterranean Cuisine', u'Winghart\u2019s Burger & Whiskey Bar', u'Muddy Waters Oyster Bar', u'Pear and the Pickle, Cafe & Market', u'Station', u'Smiling Banana Leaf', u'Piccolo Forno', u'Simple Gourmet', u'Sienna Mercato', u'Everyday Noodles']}
# 2016-11-02 12:46:05 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=50> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=40)
# 2016-11-02 12:46:05 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=50>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:05 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=50>
# {'review': [4.5, 4.0, 4.5, 4.5, 4.5, 5.0, 4.5, 4.0, 4.5, 4.0], 'review_counts': [33, 149, 168, 47, 294, 27, 44, 312, 70, 135], 'restaurant_name': [u'Pasha Cafe Lounge', u'YinzBurgh BBQ', u'Dish Osteria and Bar', u'Applewood Smoke Burger Company', u'The Dor-Stop Restaurant', u'Family Restaurant', u'Hog\u2019s Head Bar & Grill', u'Seviche', u'Big Shot Bob\u2019s House of Wings - Avalon', u'Kaleidoscope Caf\xe9']}
# 2016-11-02 12:46:07 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=60> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=50)
# 2016-11-02 12:46:07 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=60>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:07 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=60>
# {'review': [4.0, 4.0, 4.0, 4.5, 4.0, 4.0, 4.0, 4.0, 4.0, 4.5], 'review_counts': [410, 96, 217, 59, 239, 150, 245, 195, 261, 63], 'restaurant_name': [u'Deluca\u2019s Diner', u'Subba', u'Bar Marco', u'Showcase BBQ', u'Pusadee\u2019s Garden', u'Bigham Tavern', u'Spoon', u'Oishii Bento', u'Luke Wholey\u2019s Wild Alaskan Grille', u'Turkish Kebab House']}
# 2016-11-02 12:46:09 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=70> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=60)
# 2016-11-02 12:46:09 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=70>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:09 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=70>
# {'review': [4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.5, 4.0, 4.0, 4.5], 'review_counts': [488, 191, 263, 271, 93, 121, 63, 65, 303, 285], 'restaurant_name': [u'Hofbrauhaus Pittsburgh', u'Avenue B', u'Spice Island Tea House', u'G & G Noodle Bar', u'The Vandal', u'Teppanyaki Kyoto', u'Triangle Bar & Grill', u'Sichuan Gourmet', u'Tessaro\u2019s', u'Piper\u2019s Pub']}
# 2016-11-02 12:46:12 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=80> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=70)
# 2016-11-02 12:46:12 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=80>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:12 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=80>
# {'review': [4.0, 4.5, 4.0, 4.0, 4.0, 4.0, 4.5, 4.0, 4.5, 4.0], 'review_counts': [310, 54, 73, 115, 181, 67, 36, 218, 51, 244], 'restaurant_name': [u'Nicky\u2019s Thai Kitchen', u'The Greek Gourmet', u'Nadine\u2019s', u'Carmi Family Restaurant', u'The Urban Tap', u'The Summit', u'Sesame Garden', u'Shiloh Grill', u'Madonna\u2019s Mediterranean Cuisine', u'Tram\u2019s Kitchen']}
# 2016-11-02 12:46:13 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=90> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=80)
# 2016-11-02 12:46:14 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=90>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:14 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=90>
# {'review': [4.5, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.5, 4.0, 4.0], 'review_counts': [26, 65, 163, 66, 148, 326, 121, 62, 136, 89], 'restaurant_name': [u'Kevin\u2019s Deli', u'Kavsar Restaurant', u'Sienna On The Square', u'Spork', u'Hough\u2019s', u'Square Cafe', u'El Burro', u'Michael\u2019s Pizza Bar & Restaurant', u'Big Jim\u2019s Restaurant & Bar', u'Cambod-Ican Kitchen']}
# 2016-11-02 12:46:17 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=100> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=90)
# 2016-11-02 12:46:17 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=100>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:17 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=100>
# {'review': [4.0, 4.0, 5.0, 3.5, 4.0, 4.0, 4.0, 4.0, 3.5, 4.0], 'review_counts': [73, 86, 14, 250, 179, 102, 73, 182, 275, 72], 'restaurant_name': [u'Umami', u'Carmella\u2019s Plates & Pints', u'Grandma B\u2019s', u'Smoke BBQ Taqueria', u'Bluebird Kitchen', u'Legends of The North Shore', u'Cafe io', u'Tamarind', u'The Commoner', u'Cafe Zinho']}
# 2016-11-02 12:46:19 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=110> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=100)
# 2016-11-02 12:46:19 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=110>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:19 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=110>
# {'review': [4.0, 4.0, 4.5, 4.5, 4.0, 4.0, 4.0, 3.5, 4.0, 3.5], 'review_counts': [173, 142, 128, 30, 79, 265, 416, 132, 154, 374], 'restaurant_name': [u'Max\u2019s Allegheny Tavern', u'Red Oak Cafe', u'Eden', u'Conicella Pizza', u'Pastitsio', u'Union Grill', u'Burgatory', u'Brillobox', u'Tan Lac Vien', u'NOLA']}
# 2016-11-02 12:46:21 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=120> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=110)
# 2016-11-02 12:46:21 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=120>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:21 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=120>
# {'review': [3.5, 5.0, 4.0, 3.5, 4.0, 4.0, 4.0, 3.5, 4.0, 4.0], 'review_counts': [176, 24, 80, 778, 81, 104, 116, 51, 51, 123], 'restaurant_name': [u'Tender Bar & Kitchen', u'Sam\u2019s Sun Sandwich', u'Stagioni', u'Church Brew Works', u'Micro Diner', u'Crepes Parisiennes', u'Daphne Cafe', u'Scratch Food & Beverage', u'Dijlah Restaurant', u'Stone Neapolitan Pizzeria']}
# 2016-11-02 12:46:23 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=130> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=120)
# 2016-11-02 12:46:23 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=130>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:23 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=130>
# {'review': [3.5, 4.0, 4.0, 3.5, 4.0, 4.0, 4.0, 4.5, 3.5, 3.5], 'review_counts': [397, 40, 192, 983, 110, 60, 23, 33, 199, 235], 'restaurant_name': [u'The Porch at Schenley', u'Lola Bistro', u'Sichuan Gourmet', u'Primanti Bros.', u'Penn Avenue Fish Company', u'Apsara Cafe', u'Allegheny Sandwich Shoppe', u'El Milagro', u'James Street Gastropub & Speakeasy', u'Fuel & Fuddle']}
# 2016-11-02 12:46:24 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=140> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=130)
# 2016-11-02 12:46:25 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=140>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:25 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=140>
# {'review': [4.0, 4.5, 5.0, 5.0, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0], 'review_counts': [254, 42, 25, 14, 143, 145, 96, 49, 70, 122], 'restaurant_name': [u'Mercurio\u2019s', u'Parker\u2019s PGH', u'Arancini House', u'North Shore Deli', u'Benjamins Western Avenue Burger Bar', u'Aladdin\u2019s Eatery- Pittsburgh- Squirrel Hill', u'Kassab\u2019s', u'Birmingham Bridge Tavern', u'Pizza Taglio', u'Sausalido']}
# 2016-11-02 12:46:27 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=150> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=140)
# 2016-11-02 12:46:27 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=150>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:27 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=150>
# {'review': [4.0, 4.0, 4.0, 4.0, 3.5, 3.5, 4.0, 4.0, 4.0, 4.5], 'review_counts': [309, 83, 96, 34, 158, 35, 89, 185, 75, 26], 'restaurant_name': [u'Waffles Incaffeinated', u'Dive Bar & Grill', u'Independent Brewing Company', u'Peanut Butter Jelly Time', u'The Library', u'Joe & Pie', u'Little Bangkok In the Strip', u'Spak Brothers Pizza and More', u'La Feria', u'E Town Bar and Grille']}
# 2016-11-02 12:46:28 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=160> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=150)
# 2016-11-02 12:46:28 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=160>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:28 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=160>
# {'review': [4.0, 4.5, 4.0, 4.0, 5.0, 4.5, 4.0, 4.0, 4.0, 4.5], 'review_counts': [53, 60, 109, 106, 13, 229, 60, 90, 116, 76], 'restaurant_name': [u'Peppi\u2019s', u'Pitaland', u'Salem\u2019s Market & Grill', u'Bangal Kabab House and Restaurant', u'Alfred\u2019s Deli & Market', u'Waffallonia', u'Pittsburgh Barbecue Company', u'Thai Spoon', u'Murray Avenue Grill', u'Naya Cuisine']}
# 2016-11-02 12:46:30 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=170> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=160)
# 2016-11-02 12:46:30 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=170>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:30 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=170>
# {'review': [4.0, 4.0, 3.5, 3.5, 3.5, 4.0, 4.5, 3.5, 4.5, 4.0], 'review_counts': [46, 106, 123, 329, 72, 38, 78, 142, 98, 48], 'restaurant_name': [u'Bea Taco Town', u'Thin Man Sandwich Shop', u'Winghart\u2019s Burger & Whiskey Bar', u'Coca Cafe', u'Sukhothai Bistro', u'Benny Fierro\u2019s', u'Tootie\u2019s Famous Italian Beef', u'Hello Bistro', u'Joseph Tambellini Restaurant', u'Make Your Mark']}
# 2016-11-02 12:46:32 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=180> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=170)
# 2016-11-02 12:46:32 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=180>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:32 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=180>
# {'review': [4.0, 3.5, 4.5, 5.0, 4.0, 4.5, 4.5, 3.5, 4.0, 3.5], 'review_counts': [108, 81, 43, 20, 126, 46, 39, 121, 291, 194], 'restaurant_name': [u'Los Cabos Mexican Restaurant', u'Vue 412', u'Bistro To Go', u'Groceria Merante', u'Jade Grille', u'Salim\u2019s Middle Eastern Food Store', u'BFG Caf\xe9', u'STACK\u2019D Burgers & Beer', u'Casbah', u'The Yard Gastropub']}
# 2016-11-02 12:46:34 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=190> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=180)
# 2016-11-02 12:46:34 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=190>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:34 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=190>
# {'review': [3.5, 3.5, 4.0, 4.0, 4.0, 4.5, 4.5, 3.5, 4.0, 3.5], 'review_counts': [394, 174, 122, 63, 77, 41, 298, 294, 41, 490], 'restaurant_name': [u'Industry Public House', u'Penn Brewery', u'Cioppino', u'Bea Taco Town', u'Angkor Restaurant', u'Istanbul Grille', u'D\u2019s Six Pax & Dogz', u'Sonoma Grille', u'Hunan Bar', u'Primanti Bros.']}
# 2016-11-02 12:46:36 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=200> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=190)
# 2016-11-02 12:46:36 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=200>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:36 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=200>
# {'review': [3.5, 3.5, 4.5, 4.5, 4.0, 3.5, 4.0, 3.5, 3.5, 4.0], 'review_counts': [225, 80, 11, 32, 338, 160, 57, 388, 55, 59], 'restaurant_name': [u'Girasole Restaurant', u'The Fire Side Public House', u'Krista\u2019s Cantina', u'Randita\u2019s Organic Vegan Cafe', u'P&G\u2019s Pamela\u2019s Diner', u'Shady Grove', u'Pamela\u2019s', u'Union Pig & Chicken', u'Remedy', u'Sarafino\u2019s Pasta and Pizza']}
# 2016-11-02 12:46:39 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=210> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=200)
# 2016-11-02 12:46:39 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=210>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:39 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=210>
# {'review': [4.0, 4.0, 4.0, 3.5, 4.0, 3.5, 4.0, 4.0, 4.0, 4.0], 'review_counts': [78, 64, 84, 375, 74, 118, 108, 77, 142, 67], 'restaurant_name': [u'Lot 17', u'Sidelines Bar & Grill', u'Whitfield', u'BRGR', u'Pho Minh', u'Braddock\u2019s Pittsburgh Brasserie', u'Cafe Moulin', u'Totopo Mexican Kitchen and Bar', u'Chicken Latino', u'Thai Cottage']}
# 2016-11-02 12:46:41 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=220> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=210)
# 2016-11-02 12:46:41 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=220>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:41 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=220>
# {'review': [3.5, 3.5, 3.5, 3.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5], 'review_counts': [290, 94, 84, 81, 45, 29, 118, 191, 92, 31], 'restaurant_name': [u'Rose Tea Caf\xe9', u'La Tavola Italiana', u'Pan', u'Revel + Roost', u'Geppetto Cafe', u'Kabob-G Grill', u'Sushi Fuku', u'How Lee Chinese Food', u'Chick\u2019n Bubbly', u'Kickback Pinball Cafe']}
# 2016-11-02 12:46:43 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=230> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=220)
# 2016-11-02 12:46:43 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=230>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:43 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=230>
# {'review': [4.0, 4.5, 3.5, 4.5, 4.0, 4.0, 3.5, 3.5, 4.5, 4.5], 'review_counts': [90, 123, 275, 15, 112, 169, 197, 325, 33, 23], 'restaurant_name': [u'Hal\u2019s Bar and Grill', u'Green Forest Churrascaria', u'Round Corner Cantina', u'Leon\u2019s Caribbean Restaurant', u'Eddie Merlot\u2019s - Pittsburgh', u'Robert Wholey and Co Fish Market', u'Ramen Bar', u'Double Wide Grill', u'La Gondola Pizzeria & Restaurant', u'Moonlite Cafe']}
# 2016-11-02 12:46:45 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=240> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=230)
# 2016-11-02 12:46:45 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=240>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:45 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=240>
# {'review': [3.5, 4.5, 4.0, 4.0, 4.0, 4.5, 4.0, 3.5, 4.5, 4.0], 'review_counts': [235, 203, 37, 84, 82, 36, 116, 268, 123, 64], 'restaurant_name': [u'Mad Mex - Shadyside', u'Fiori\u2019s Pizzaria', u'Adolfo\u2019s Restaurant', u'NU Jewish Bistro', u'Squirrel Hill Cafe', u'Yovi\u2019s', u'Umi', u'Harris Grill', u'S&D Polish Deli', u'Pints On Penn']}
# 2016-11-02 12:46:46 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=250> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=240)
# 2016-11-02 12:46:46 [scrapy] INFO: Crawled 26 pages (at 26 pages/min), scraped 50 items (at 50 items/min)
# 2016-11-02 12:46:46 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=250>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:46 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=250>
# {'review': [4.5, 4.5, 4.5, 3.5, 3.5, 4.5, 4.0, 3.5, 3.5, 3.5], 'review_counts': [9, 46, 17, 61, 159, 13, 78, 57, 59, 70], 'restaurant_name': [u'Living Juicy', u'Pastoli\u2019s Pizza, Pasta & Paisans', u'Two Louie\u2019s Market', u'Cafe Sam', u'Pizzaiolo Primo', u'Z-Best BBQ', u'Armstrong\u2019s', u'Zarra\u2019s A Taste of Southern Italy', u'Nak Won Garden', u'The BeerHive']}
# 2016-11-02 12:46:48 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=260> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=250)
# 2016-11-02 12:46:48 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=260>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:48 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=260>
# {'review': [4.0, 4.5, 4.0, 3.5, 4.0, 4.0, 4.0, 5.0, 4.0, 4.5], 'review_counts': [27, 23, 86, 101, 71, 44, 98, 6, 181, 54], 'restaurant_name': [u'Cucina Vitale', u'The Dream BBQ', u'Pizza Perfectta', u'Bella Notte', u'Uncle Sam\u2019s Submarines', u'My Thai', u'Ginza', u'Don\u2019s Diner', u'The Capital Grille', u'Pelegrino\u2019s Pizza & Pasta']}
# 2016-11-02 12:46:50 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=270> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=260)
# 2016-11-02 12:46:50 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=270>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:50 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=270>
# {'review': [4.5, 3.5, 3.5, 3.5, 4.0, 3.0, 3.5, 4.0, 4.0, 4.5], 'review_counts': [102, 108, 76, 53, 55, 258, 271, 20, 14, 28], 'restaurant_name': [u'Carson Street Deli & Craft Beer Bar', u'Casa Rasta', u'Grandview Saloon', u'Top Shabu-Shabu & Lounge', u'Amels', u'Six Penn Kitchen', u'Grand Concourse', u'Grant Bar', u'The Real McCoy Sandwich Shop', u'Sushi & Rolls']}
# 2016-11-02 12:46:52 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=280> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=270)
# 2016-11-02 12:46:52 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=280>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:52 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=280>
# {'review': [3.5, 3.5, 3.5, 3.5, 4.5, 3.5, 3.5, 4.0, 4.5, 3.5], 'review_counts': [233, 88, 214, 220, 14, 122, 224, 29, 36, 58], 'restaurant_name': [u'Primanti Bros.', u'Smoq Pitt', u'Olive or Twist', u'Sharp Edge', u'Jolina\u2019s Mediterranean Cuisine', u'The Yard', u'Mad Mex - Oakland', u'Mezzo', u'Yeung\u2019s House', u'Hello Bistro']}
# 2016-11-02 12:46:54 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=290> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=280)
# 2016-11-02 12:46:54 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=290>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:55 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=290>
# {'review': [4.0, 4.5, 3.5, 3.5, 4.0, 5.0, 3.5, 4.0, 4.0, 4.0], 'review_counts': [209, 7, 86, 76, 49, 15, 339, 93, 65, 11], 'restaurant_name': [u'Il Pizzaiolo', u'TMD', u'Ephesus Mediterranean Kitchen', u'The Abbey on Butler', u'Aladdin\u2019s Eatery', u'Nox\u2019s Tavern and Grille', u'Lidia\u2019s', u'Reyna Foods', u'Feng Japanese Steak Hibachi & Sushi House', u'South Side BBQ Company']}
# 2016-11-02 12:46:57 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=300> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=290)
# 2016-11-02 12:46:57 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=300>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:57 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=300>
# {'review': [3.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.0, 3.5, 4.0, 4.0], 'review_counts': [165, 7, 307, 232, 53, 18, 37, 105, 86, 188], 'restaurant_name': [u'Hokkaido Seafood Buffet', u'Mattress Factory Caf\xe9', u'Central Diner & Grille', u'P&G\u2019s Pamela\u2019s Diner', u'Luma Restaurant', u'Tavern 51', u'The Mediterranean Grill', u'Kelly O\u2019s Diner', u'Aladdin\u2019s Eatery', u'Chaya Japanese Cuisine']}
# 2016-11-02 12:46:59 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=310> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=300)
# 2016-11-02 12:46:59 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=310>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:46:59 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=310>
# {'review': [4.0, 3.5, 5.0, 4.0, 3.5, 3.5, 3.5, 3.0, 3.5, 3.5], 'review_counts': [115, 110, 6, 23, 27, 165, 36, 152, 152, 133], 'restaurant_name': [u'Pamela\u2019s Upstreet Diner', u'Green Pepper', u'The Alcove', u'Chateau Caf\xe9 & Cakery', u'Giorgio\u2019s Place', u'Casa Reyna', u'Tipsy Cow', u'Local Bar + Kitchen', u'Plum Pan Asian Kitchen', u'Diamond Market Bar & Grill']}
# 2016-11-02 12:47:01 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=320> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=310)
# 2016-11-02 12:47:01 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=320>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:01 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=320>
# {'review': [4.0, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 3.5], 'review_counts': [23, 180, 23, 24, 66, 12, 56, 34, 31, 58], 'restaurant_name': [u'Caf\xe9 Cravings', u'Paris 66', u'Wilson\u2019s Bar-B-Q', u'Great Harvest Bread Co', u'No. 1 Sushi Sushi', u'Johnny\u2019s Diner', u'Atria\u2019s', u'The Foundry Table & Tap', u'Beta Bites', u'Pizza Milano']}
# 2016-11-02 12:47:03 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=330> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=320)
# 2016-11-02 12:47:04 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=330>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:04 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=330>
# {'review': [4.0, 3.5, 4.0, 4.5, 3.0, 3.0, 4.5, 3.0, 4.0, 4.0], 'review_counts': [34, 131, 251, 34, 267, 100, 30, 176, 145, 90], 'restaurant_name': [u'51 Wings and Things', u'Dinette', u'Soba', u'Ting\u2019s Kitchen', u'Ten Penny', u'SoHo', u'Nancy\u2019s East End Diner', u'Caliente Pizza & Draft House', u'The Zenith', u'Red Orchid']}
# 2016-11-02 12:47:06 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=340> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=330)
# 2016-11-02 12:47:06 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=340>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:06 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=340>
# {'review': [3.5, 4.5, 4.0, 4.0, 3.5, 3.5, 3.5, 3.0, 4.0, 4.5], 'review_counts': [103, 306, 99, 59, 11, 56, 33, 162, 32, 21], 'restaurant_name': [u'Thai Hana', u'La Gourmandine Bakery & Pastry Shop', u'All India', u'Silky\u2019s Pub', u'Mullin\u2019s Diner', u'Chengdu Gourmet', u'The Map Room Grill & Bar', u'Social', u'Luke and Mike\u2019s Frontporch', u'Wesley\u2019s Delicatessen & Catering']}
# 2016-11-02 12:47:08 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=350> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=340)
# 2016-11-02 12:47:08 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=350>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:08 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=350>
# {'review': [3.0, 4.5, 4.0, 5.0, 4.0, 3.5, 3.5, 4.5, 4.5, 4.5], 'review_counts': [118, 20, 184, 5, 126, 21, 158, 38, 20, 7], 'restaurant_name': [u'Le Mont', u'Cafe\u2019 33', u'Thai Cuisine', u'Rudy Martino Original House of Submarines', u'The Enrico Biscotti', u'Siam Thai Restaurant', u'P&G\u2019s Pamela\u2019s Diner', u'DeLallo\u2019s Fort Couch Cafe', u'Jamison\u2019s On West Liberty', u'Giovanni\u2019s Pizza & Restaurant']}
# 2016-11-02 12:47:10 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=360> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=350)
# 2016-11-02 12:47:10 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=360>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:10 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=360>
# {'review': [4.0, 4.0, 4.5, 4.0, 4.5, 3.5, 4.0, 4.5, 3.5, 4.5], 'review_counts': [87, 44, 17, 82, 13, 155, 76, 16, 186, 32], 'restaurant_name': [u'Primanti Bros.', u'Someone Else\u2019s Bar', u'Craftwork Kitchen', u'Uncle Sam\u2019s Submarines', u'Corner Mercantile', u'Ritters Diner', u'Stoke\u2019s Grill', u'Deli On North Avenue', u'Mallorca Restaurant', u'Arnold\u2019s Tea']}
# 2016-11-02 12:47:11 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=370> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=360)
# 2016-11-02 12:47:11 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=370>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:11 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=370>
# {'review': [3.5, 4.0, 3.5, 4.5, 4.0, 3.5, 4.0, 4.0, 4.0, 3.5], 'review_counts': [110, 24, 55, 13, 32, 53, 158, 73, 45, 27], 'restaurant_name': [u'Savoy', u'Fredos Deli', u'SAKE Asian Cuisine & Sushi Bar', u'Istanbul Grille', u'Stinky\u2019s Bar & Grill', u'Hello Bistro', u'OTB Bicycle Caf\xe9', u'Smokin\u2019 Joe\u2019s', u'Wild Rosemary', u'Kretzler\u2019s Tavern']}
# 2016-11-02 12:47:13 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=380> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=370)
# 2016-11-02 12:47:13 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=380>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:13 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=380>
# {'review': [4.0, 4.0, 4.5, 4.0, 3.0, 4.0, 4.0, 3.5, 4.0, 3.5], 'review_counts': [27, 83, 22, 26, 100, 46, 24, 139, 22, 33], 'restaurant_name': [u'Peppi\u2019s', u'Kiku Japanese Restaurant', u'City Oven', u'Afamia Mediterranean Grille', u'Rivertowne', u'Pallantia Tapas de Espa\xf1a', u'Bombay Gyro\u2019s and Lunch Box', u'Sun Penang', u'Wicked Fox', u'Village Tavern and Trattoria']}
# 2016-11-02 12:47:15 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=390> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=380)
# 2016-11-02 12:47:15 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=390>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:15 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=390>
# {'review': [4.0, 4.5, 3.5, 3.5, 3.0, 3.0, 3.5, 3.5, 4.0, 3.5], 'review_counts': [19, 88, 109, 32, 105, 90, 87, 98, 77, 87], 'restaurant_name': [u'The Huddle', u'The Pretzel Shop', u'Wai Wai Chinese Cuisine', u'Stack\u2019d Burgers & Beer', u'Original Oyster House', u'Cornerstone Restaurant & Bar', u'The Livermore', u'Alexander\u2019s Italian Bistro', u'SLICE on Broadway', u'Poros']}
# 2016-11-02 12:47:17 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=400> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=390)
# 2016-11-02 12:47:17 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=400>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:17 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=400>
# {'review': [5.0, 3.5, 4.0, 3.5, 4.0, 4.5, 4.0, 4.0, 3.5, 3.0], 'review_counts': [4, 77, 99, 92, 24, 31, 93, 32, 73, 107], 'restaurant_name': [u'Heinz USA', u'Korea Garden', u'The Melting Pot', u'Willow Restaurant', u'Frank & Shirley\u2019s Restaurant', u'Groceria Italiana', u'Little Tokyo Bistro', u'Jozsa Corner', u'Creekhouse', u'Redbeard\u2019s On Sixth']}
# 2016-11-02 12:47:19 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=410> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=400)
# 2016-11-02 12:47:19 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=410>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:19 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=410>
# {'review': [4.5, 3.5, 3.5, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0, 3.5], 'review_counts': [52, 93, 130, 128, 79, 35, 24, 69, 98, 61], 'restaurant_name': [u'Hartwood Restaurant & Whispers Pub', u'Hemingway\u2019s Cafe', u'Texas de Brazil', u'Vietnam\u2019s Pho', u'Vincent\u2019s Pizza Park', u'O\u2019Leary\u2019s', u'Wang\u2019s Kitchen', u'Barb\u2019s Corner Kitchen', u'Curry on Murray', u'Hambone\u2019s Neighborhood Bar and Grill']}
# 2016-11-02 12:47:21 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=420> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=410)
# 2016-11-02 12:47:21 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=420>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:21 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=420>
# {'review': [3.5, 4.5, 4.0, 4.5, 3.5, 3.5, 4.0, 4.5, 3.0, 4.0], 'review_counts': [56, 63, 15, 11, 157, 40, 41, 15, 332, 66], 'restaurant_name': [u'Vincent\u2019s of Greentree', u'Deli on Butler Street', u'The Elbow Room', u'Pork and Beans', u'Silk Elephant', u'Wings Over Pittsburgh', u'V3 Flatbread Pizza', u'Tasty N Healthy', u'Lulu\u2019s Noodles', u'Mike & Tony\u2019s Gyros']}
# 2016-11-02 12:47:25 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=430> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=420)
# 2016-11-02 12:47:25 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=430>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:25 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=430>
# {'review': [4.0, 4.0, 4.5, 3.5, 3.5, 3.5, 3.5, 4.0, 3.5, 3.5], 'review_counts': [82, 15, 6, 19, 114, 67, 39, 21, 111, 119], 'restaurant_name': [u'Bloomfield Bridge Tavern', u'Robbie\u2019s Super-Stuff Super-Licious Bbq Restaurant', u'Mama Rose', u'Rasta House Caribbean Resturant', u'BD\u2019s Mongolian Grill', u'Ka Mei', u'Arpino Trattoria', u'Fireside Caribbean Restaurant', u'Eat Unique', u'Nine On Nine']}
# 2016-11-02 12:47:27 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=440> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=430)
# 2016-11-02 12:47:27 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=440>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:27 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=440>
# {'review': [4.0, 3.5, 4.0, 3.0, 4.0, 3.5, 3.0, 4.5, 4.5, 4.0], 'review_counts': [77, 34, 57, 106, 12, 140, 39, 7, 8, 19], 'restaurant_name': [u'People\u2019s Indian Restaurant', u'Lindos Restaurant', u'Packs & Dogs', u'Bill\u2019s Bar & Burger', u'Buon Giorno Cafe', u'Thai Me Up', u'The Simple Greek', u'S&D Cafe', u'Soul Food Connection', u'Love Yogurt']}
# 2016-11-02 12:47:30 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=450> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=440)
# 2016-11-02 12:47:30 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=450>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:30 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=450>
# {'review': [3.5, 3.5, 4.0, 3.5, 4.0, 3.5, 4.0, 3.5, 4.5, 4.0], 'review_counts': [29, 49, 155, 173, 364, 36, 28, 12, 53, 22], 'restaurant_name': [u'Sammy\u2019s Famous Corned Beef', u'Mekong Restaurant', u'Beto\u2019s Pizza', u'The Cheesecake Factory', u'Burgatory', u'Monte Cello\u2019s', u'Smallman Street Deli', u'The Jaggerbush', u'Rey Azteca', u'Restaurant Hana']}
# 2016-11-02 12:47:32 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=460> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=450)
# 2016-11-02 12:47:32 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=460>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:32 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=460>
# {'review': [3.5, 4.0, 3.5, 4.5, 4.5, 3.5, 3.5, 4.0, 4.0, 3.0], 'review_counts': [26, 22, 110, 121, 8, 54, 50, 24, 57, 42], 'restaurant_name': [u'Tan Izakaya', u'Excuses Bar & Grill', u'Tonic Bar & Grill', u'Tazza D\u2019oro Cafe & Espresso Bar', u'Pittsburgh Poultry Company', u'Bartram House Bakery & Cafe', u'Osteria 2350', u'Thai Touch Kitchen', u'Drew\u2019s Family Restaurant', u'Bella Vista']}
# 2016-11-02 12:47:34 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=470> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=460)
# 2016-11-02 12:47:34 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=470>
# {'review': [], 'review_counts': [], 'restaurant_name': []}
# 2016-11-02 12:47:34 [scrapy] DEBUG: Scraped from <200 https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=470>
# {'review': [3.0, 4.0, 3.5, 4.0, 3.5, 4.0, 4.5, 3.5, 4.5, 3.5], 'review_counts': [53, 97, 40, 134, 19, 154, 13, 107, 12, 82], 'restaurant_name': [u'Orient Kitchen', u'Chinatown Inn', u'Cibo', u'Little Tokyo', u'Gandy Dancer Saloon', u'Gaby Et Jules', u'Pittsburgh Pretzel Cafe', u'Bado\u2019s Pizza Grill and Ale House', u'That\u2019s Amore', u'Patron Mexican Grill']}
# 2016-11-02 12:47:36 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=480> (referer: https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh%2C+PA&start=470)
# ...
# {"review": [3.5, 5.0, 4.0, 3.5, 4.0, 4.0, 4.0, 3.5, 4.0, 4.0], "restaurant_name": ["Tender Bar & Kitchen", "Sam\u2019s Sun Sandwich", "Stagioni", "Church Brew Works", "Micro Diner", "Crepes Parisiennes", "Daphne Cafe", "Scratch Food & Beverage", "Dijlah Restaurant", "Stone Neapolitan Pizzeria"], "review_counts": [176, 24, 80, 778, 81, 104, 116, 51, 51, 123]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.0, 4.0, 3.5, 4.0, 4.0, 4.0, 4.5, 3.5, 3.5], "restaurant_name": ["The Porch at Schenley", "Lola Bistro", "Sichuan Gourmet", "Primanti Bros.", "Penn Avenue Fish Company", "Apsara Cafe", "Allegheny Sandwich Shoppe", "El Milagro", "James Street Gastropub & Speakeasy", "Fuel & Fuddle"], "review_counts": [397, 40, 192, 983, 110, 60, 23, 33, 199, 235]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 5.0, 5.0, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0], "restaurant_name": ["Mercurio\u2019s", "Parker\u2019s PGH", "Arancini House", "North Shore Deli", "Benjamins Western Avenue Burger Bar", "Aladdin\u2019s Eatery- Pittsburgh- Squirrel Hill", "Kassab\u2019s", "Birmingham Bridge Tavern", "Pizza Taglio", "Sausalido"], "review_counts": [254, 42, 25, 14, 143, 145, 96, 49, 70, 122]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 4.0, 4.0, 3.5, 3.5, 4.0, 4.0, 4.0, 4.5], "restaurant_name": ["Waffles Incaffeinated", "Dive Bar & Grill", "Independent Brewing Company", "Peanut Butter Jelly Time", "The Library", "Joe & Pie", "Little Bangkok In the Strip", "Spak Brothers Pizza and More", "La Feria", "E Town Bar and Grille"], "review_counts": [309, 83, 96, 34, 158, 35, 89, 185, 75, 26]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 4.0, 4.0, 5.0, 4.5, 4.0, 4.0, 4.0, 4.5], "restaurant_name": ["Peppi\u2019s", "Pitaland", "Salem\u2019s Market & Grill", "Bangal Kabab House and Restaurant", "Alfred\u2019s Deli & Market", "Waffallonia", "Pittsburgh Barbecue Company", "Thai Spoon", "Murray Avenue Grill", "Naya Cuisine"], "review_counts": [53, 60, 109, 106, 13, 229, 60, 90, 116, 76]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 3.5, 3.5, 3.5, 4.0, 4.5, 3.5, 4.5, 4.0], "restaurant_name": ["Bea Taco Town", "Thin Man Sandwich Shop", "Winghart\u2019s Burger & Whiskey Bar", "Coca Cafe", "Sukhothai Bistro", "Benny Fierro\u2019s", "Tootie\u2019s Famous Italian Beef", "Hello Bistro", "Joseph Tambellini Restaurant", "Make Your Mark"], "review_counts": [46, 106, 123, 329, 72, 38, 78, 142, 98, 48]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 4.5, 5.0, 4.0, 4.5, 4.5, 3.5, 4.0, 3.5], "restaurant_name": ["Los Cabos Mexican Restaurant", "Vue 412", "Bistro To Go", "Groceria Merante", "Jade Grille", "Salim\u2019s Middle Eastern Food Store", "BFG Caf\u00e9", "STACK\u2019D Burgers & Beer", "Casbah", "The Yard Gastropub"], "review_counts": [108, 81, 43, 20, 126, 46, 39, 121, 291, 194]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 3.5, 4.0, 4.0, 4.0, 4.5, 4.5, 3.5, 4.0, 3.5], "restaurant_name": ["Industry Public House", "Penn Brewery", "Cioppino", "Bea Taco Town", "Angkor Restaurant", "Istanbul Grille", "D\u2019s Six Pax & Dogz", "Sonoma Grille", "Hunan Bar", "Primanti Bros."], "review_counts": [394, 174, 122, 63, 77, 41, 298, 294, 41, 490]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 3.5, 4.5, 4.5, 4.0, 3.5, 4.0, 3.5, 3.5, 4.0], "restaurant_name": ["Girasole Restaurant", "The Fire Side Public House", "Krista\u2019s Cantina", "Randita\u2019s Organic Vegan Cafe", "P&G\u2019s Pamela\u2019s Diner", "Shady Grove", "Pamela\u2019s", "Union Pig & Chicken", "Remedy", "Sarafino\u2019s Pasta and Pizza"], "review_counts": [225, 80, 11, 32, 338, 160, 57, 388, 55, 59]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 4.0, 3.5, 4.0, 3.5, 4.0, 4.0, 4.0, 4.0], "restaurant_name": ["Lot 17", "Sidelines Bar & Grill", "Whitfield", "BRGR", "Pho Minh", "Braddock\u2019s Pittsburgh Brasserie", "Cafe Moulin", "Totopo Mexican Kitchen and Bar", "Chicken Latino", "Thai Cottage"], "review_counts": [78, 64, 84, 375, 74, 118, 108, 77, 142, 67]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 3.5, 3.5, 3.5, 4.0, 4.5, 4.0, 4.0, 4.0, 4.5], "restaurant_name": ["Rose Tea Caf\u00e9", "La Tavola Italiana", "Pan", "Revel + Roost", "Geppetto Cafe", "Kabob-G Grill", "Sushi Fuku", "How Lee Chinese Food", "Chick\u2019n Bubbly", "Kickback Pinball Cafe"], "review_counts": [290, 94, 84, 81, 45, 29, 118, 191, 92, 31]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 3.5, 4.5, 4.0, 4.0, 3.5, 3.5, 4.5, 4.5], "restaurant_name": ["Hal\u2019s Bar and Grill", "Green Forest Churrascaria", "Round Corner Cantina", "Leon\u2019s Caribbean Restaurant", "Eddie Merlot\u2019s - Pittsburgh", "Robert Wholey and Co Fish Market", "Ramen Bar", "Double Wide Grill", "La Gondola Pizzeria & Restaurant", "Moonlite Cafe"], "review_counts": [90, 123, 275, 15, 112, 169, 197, 325, 33, 23]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.5, 4.0, 4.0, 4.0, 4.5, 4.0, 3.5, 4.5, 4.0], "restaurant_name": ["Mad Mex - Shadyside", "Fiori\u2019s Pizzaria", "Adolfo\u2019s Restaurant", "NU Jewish Bistro", "Squirrel Hill Cafe", "Yovi\u2019s", "Umi", "Harris Grill", "S&D Polish Deli", "Pints On Penn"], "review_counts": [235, 203, 37, 84, 82, 36, 116, 268, 123, 64]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.5, 4.5, 4.5, 3.5, 3.5, 4.5, 4.0, 3.5, 3.5, 3.5], "restaurant_name": ["Living Juicy", "Pastoli\u2019s Pizza, Pasta & Paisans", "Two Louie\u2019s Market", "Cafe Sam", "Pizzaiolo Primo", "Z-Best BBQ", "Armstrong\u2019s", "Zarra\u2019s A Taste of Southern Italy", "Nak Won Garden", "The BeerHive"], "review_counts": [9, 46, 17, 61, 159, 13, 78, 57, 59, 70]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 4.0, 3.5, 4.0, 4.0, 4.0, 5.0, 4.0, 4.5], "restaurant_name": ["Cucina Vitale", "The Dream BBQ", "Pizza Perfectta", "Bella Notte", "Uncle Sam\u2019s Submarines", "My Thai", "Ginza", "Don\u2019s Diner", "The Capital Grille", "Pelegrino\u2019s Pizza & Pasta"], "review_counts": [27, 23, 86, 101, 71, 44, 98, 6, 181, 54]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.5, 3.5, 3.5, 3.5, 4.0, 3.0, 3.5, 4.0, 4.0, 4.5], "restaurant_name": ["Carson Street Deli & Craft Beer Bar", "Casa Rasta", "Grandview Saloon", "Top Shabu-Shabu & Lounge", "Amels", "Six Penn Kitchen", "Grand Concourse", "Grant Bar", "The Real McCoy Sandwich Shop", "Sushi & Rolls"], "review_counts": [102, 108, 76, 53, 55, 258, 271, 20, 14, 28]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 3.5, 3.5, 3.5, 4.5, 3.5, 3.5, 4.0, 4.5, 3.5], "restaurant_name": ["Primanti Bros.", "Smoq Pitt", "Olive or Twist", "Sharp Edge", "Jolina\u2019s Mediterranean Cuisine", "The Yard", "Mad Mex - Oakland", "Mezzo", "Yeung\u2019s House", "Hello Bistro"], "review_counts": [233, 88, 214, 220, 14, 122, 224, 29, 36, 58]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 3.5, 3.5, 4.0, 5.0, 3.5, 4.0, 4.0, 4.0], "restaurant_name": ["Il Pizzaiolo", "TMD", "Ephesus Mediterranean Kitchen", "The Abbey on Butler", "Aladdin\u2019s Eatery", "Nox\u2019s Tavern and Grille", "Lidia\u2019s", "Reyna Foods", "Feng Japanese Steak Hibachi & Sushi House", "South Side BBQ Company"], "review_counts": [209, 7, 86, 76, 49, 15, 339, 93, 65, 11]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.5, 4.5, 4.0, 4.0, 4.5, 4.0, 3.5, 4.0, 4.0], "restaurant_name": ["Hokkaido Seafood Buffet", "Mattress Factory Caf\u00e9", "Central Diner & Grille", "P&G\u2019s Pamela\u2019s Diner", "Luma Restaurant", "Tavern 51", "The Mediterranean Grill", "Kelly O\u2019s Diner", "Aladdin\u2019s Eatery", "Chaya Japanese Cuisine"], "review_counts": [165, 7, 307, 232, 53, 18, 37, 105, 86, 188]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 5.0, 4.0, 3.5, 3.5, 3.5, 3.0, 3.5, 3.5], "restaurant_name": ["Pamela\u2019s Upstreet Diner", "Green Pepper", "The Alcove", "Chateau Caf\u00e9 & Cakery", "Giorgio\u2019s Place", "Casa Reyna", "Tipsy Cow", "Local Bar + Kitchen", "Plum Pan Asian Kitchen", "Diamond Market Bar & Grill"], "review_counts": [115, 110, 6, 23, 27, 165, 36, 152, 152, 133]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 4.0, 3.5], "restaurant_name": ["Caf\u00e9 Cravings", "Paris 66", "Wilson\u2019s Bar-B-Q", "Great Harvest Bread Co", "No. 1 Sushi Sushi", "Johnny\u2019s Diner", "Atria\u2019s", "The Foundry Table & Tap", "Beta Bites", "Pizza Milano"], "review_counts": [23, 180, 23, 24, 66, 12, 56, 34, 31, 58]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 4.0, 4.5, 3.0, 3.0, 4.5, 3.0, 4.0, 4.0], "restaurant_name": ["51 Wings and Things", "Dinette", "Soba", "Ting\u2019s Kitchen", "Ten Penny", "SoHo", "Nancy\u2019s East End Diner", "Caliente Pizza & Draft House", "The Zenith", "Red Orchid"], "review_counts": [34, 131, 251, 34, 267, 100, 30, 176, 145, 90]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.5, 4.0, 4.0, 3.5, 3.5, 3.5, 3.0, 4.0, 4.5], "restaurant_name": ["Thai Hana", "La Gourmandine Bakery & Pastry Shop", "All India", "Silky\u2019s Pub", "Mullin\u2019s Diner", "Chengdu Gourmet", "The Map Room Grill & Bar", "Social", "Luke and Mike\u2019s Frontporch", "Wesley\u2019s Delicatessen & Catering"], "review_counts": [103, 306, 99, 59, 11, 56, 33, 162, 32, 21]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.0, 4.5, 4.0, 5.0, 4.0, 3.5, 3.5, 4.5, 4.5, 4.5], "restaurant_name": ["Le Mont", "Cafe\u2019 33", "Thai Cuisine", "Rudy Martino Original House of Submarines", "The Enrico Biscotti", "Siam Thai Restaurant", "P&G\u2019s Pamela\u2019s Diner", "DeLallo\u2019s Fort Couch Cafe", "Jamison\u2019s On West Liberty", "Giovanni\u2019s Pizza & Restaurant"], "review_counts": [118, 20, 184, 5, 126, 21, 158, 38, 20, 7]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 4.5, 4.0, 4.5, 3.5, 4.0, 4.5, 3.5, 4.5], "restaurant_name": ["Primanti Bros.", "Someone Else\u2019s Bar", "Craftwork Kitchen", "Uncle Sam\u2019s Submarines", "Corner Mercantile", "Ritters Diner", "Stoke\u2019s Grill", "Deli On North Avenue", "Mallorca Restaurant", "Arnold\u2019s Tea"], "review_counts": [87, 44, 17, 82, 13, 155, 76, 16, 186, 32]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.0, 3.5, 4.5, 4.0, 3.5, 4.0, 4.0, 4.0, 3.5], "restaurant_name": ["Savoy", "Fredos Deli", "SAKE Asian Cuisine & Sushi Bar", "Istanbul Grille", "Stinky\u2019s Bar & Grill", "Hello Bistro", "OTB Bicycle Caf\u00e9", "Smokin\u2019 Joe\u2019s", "Wild Rosemary", "Kretzler\u2019s Tavern"], "review_counts": [110, 24, 55, 13, 32, 53, 158, 73, 45, 27]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 4.5, 4.0, 3.0, 4.0, 4.0, 3.5, 4.0, 3.5], "restaurant_name": ["Peppi\u2019s", "Kiku Japanese Restaurant", "City Oven", "Afamia Mediterranean Grille", "Rivertowne", "Pallantia Tapas de Espa\u00f1a", "Bombay Gyro\u2019s and Lunch Box", "Sun Penang", "Wicked Fox", "Village Tavern and Trattoria"], "review_counts": [27, 83, 22, 26, 100, 46, 24, 139, 22, 33]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.5, 3.5, 3.5, 3.0, 3.0, 3.5, 3.5, 4.0, 3.5], "restaurant_name": ["The Huddle", "The Pretzel Shop", "Wai Wai Chinese Cuisine", "Stack\u2019d Burgers & Beer", "Original Oyster House", "Cornerstone Restaurant & Bar", "The Livermore", "Alexander\u2019s Italian Bistro", "SLICE on Broadway", "Poros"], "review_counts": [19, 88, 109, 32, 105, 90, 87, 98, 77, 87]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [5.0, 3.5, 4.0, 3.5, 4.0, 4.5, 4.0, 4.0, 3.5, 3.0], "restaurant_name": ["Heinz USA", "Korea Garden", "The Melting Pot", "Willow Restaurant", "Frank & Shirley\u2019s Restaurant", "Groceria Italiana", "Little Tokyo Bistro", "Jozsa Corner", "Creekhouse", "Redbeard\u2019s On Sixth"], "review_counts": [4, 77, 99, 92, 24, 31, 93, 32, 73, 107]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.5, 3.5, 3.5, 3.5, 4.0, 4.0, 4.0, 4.0, 4.0, 3.5], "restaurant_name": ["Hartwood Restaurant & Whispers Pub", "Hemingway\u2019s Cafe", "Texas de Brazil", "Vietnam\u2019s Pho", "Vincent\u2019s Pizza Park", "O\u2019Leary\u2019s", "Wang\u2019s Kitchen", "Barb\u2019s Corner Kitchen", "Curry on Murray", "Hambone\u2019s Neighborhood Bar and Grill"], "review_counts": [52, 93, 130, 128, 79, 35, 24, 69, 98, 61]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.5, 4.0, 4.5, 3.5, 3.5, 4.0, 4.5, 3.0, 4.0], "restaurant_name": ["Vincent\u2019s of Greentree", "Deli on Butler Street", "The Elbow Room", "Pork and Beans", "Silk Elephant", "Wings Over Pittsburgh", "V3 Flatbread Pizza", "Tasty N Healthy", "Lulu\u2019s Noodles", "Mike & Tony\u2019s Gyros"], "review_counts": [56, 63, 15, 11, 157, 40, 41, 15, 332, 66]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 4.0, 4.5, 3.5, 3.5, 3.5, 3.5, 4.0, 3.5, 3.5], "restaurant_name": ["Bloomfield Bridge Tavern", "Robbie\u2019s Super-Stuff Super-Licious Bbq Restaurant", "Mama Rose", "Rasta House Caribbean Resturant", "BD\u2019s Mongolian Grill", "Ka Mei", "Arpino Trattoria", "Fireside Caribbean Restaurant", "Eat Unique", "Nine On Nine"], "review_counts": [82, 15, 6, 19, 114, 67, 39, 21, 111, 119]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 4.0, 3.0, 4.0, 3.5, 3.0, 4.5, 4.5, 4.0], "restaurant_name": ["People\u2019s Indian Restaurant", "Lindos Restaurant", "Packs & Dogs", "Bill\u2019s Bar & Burger", "Buon Giorno Cafe", "Thai Me Up", "The Simple Greek", "S&D Cafe", "Soul Food Connection", "Love Yogurt"], "review_counts": [77, 34, 57, 106, 12, 140, 39, 7, 8, 19]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 3.5, 4.0, 3.5, 4.0, 3.5, 4.0, 3.5, 4.5, 4.0], "restaurant_name": ["Sammy\u2019s Famous Corned Beef", "Mekong Restaurant", "Beto\u2019s Pizza", "The Cheesecake Factory", "Burgatory", "Monte Cello\u2019s", "Smallman Street Deli", "The Jaggerbush", "Rey Azteca", "Restaurant Hana"], "review_counts": [29, 49, 155, 173, 364, 36, 28, 12, 53, 22]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.5, 4.0, 3.5, 4.5, 4.5, 3.5, 3.5, 4.0, 4.0, 3.0], "restaurant_name": ["Tan Izakaya", "Excuses Bar & Grill", "Tonic Bar & Grill", "Tazza D\u2019oro Cafe & Espresso Bar", "Pittsburgh Poultry Company", "Bartram House Bakery & Cafe", "Osteria 2350", "Thai Touch Kitchen", "Drew\u2019s Family Restaurant", "Bella Vista"], "review_counts": [26, 22, 110, 121, 8, 54, 50, 24, 57, 42]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [3.0, 4.0, 3.5, 4.0, 3.5, 4.0, 4.5, 3.5, 4.5, 3.5], "restaurant_name": ["Orient Kitchen", "Chinatown Inn", "Cibo", "Little Tokyo", "Gandy Dancer Saloon", "Gaby Et Jules", "Pittsburgh Pretzel Cafe", "Bado\u2019s Pizza Grill and Ale House", "That\u2019s Amore", "Patron Mexican Grill"], "review_counts": [53, 97, 40, 134, 19, 154, 13, 107, 12, 82]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# {"review": [4.0, 3.5, 3.5, 4.0, 4.0, 3.5, 3.5, 4.0, 3.5, 4.0], "restaurant_name": ["The Green Mango", "Franktuary", "I Tea Cafe", "Tsuki Japanese", "Smallman Street Deli", "Asiatique Thai Bistro", "August Henry\u2019s City Saloon", "Elevation Restaurant", "Emilliano\u2019s Mexican Restaurant and Bar", "Eggs-R-Us"], "review_counts": [121, 18, 54, 40, 93, 42, 93, 7, 187, 81]},
# {"review": [], "restaurant_name": [], "review_counts": []},
# /Users/apple/Desktop/PDS/tutorial

# %% [markdown]
# The `urljoin()` method above will build a full absolute URL and there will be a new request to next page yielded.
# Here let's walk through the mechanism of the Scrapy to get following links: when you yield a Request in a callback method, Scrapy will schedule that request to be sent and register a callback to be executed when that request finishes.

# %% [markdown]
# ### Run Scrapy using a python script
# Besides the typical way to run Scrapy via `scrapy crawl`, we can also run Scrapy using a script which is essential to show our work inside this notebook.
# Because the Scrapy is built upon the Twisted asynchronous networking library, so we need to run it inside the Twisted reactor.
# Let's get started from a single spider.
# **Please note that since Reactor is not restartable, if you want to run following script the second time, you need to relaunch jupyter notebook. You are also welcome to find out some other ways to tackle this. **

# %%
import scrapy
from scrapy.crawler import CrawlerProcess

class ScriptRunSpider(scrapy.Spider):
    name = "scriptrunspider"
    
    def start_requests(self):
        urls = [
            'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0',
            'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=10',
            'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=20',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            
    def parse(self, response):
        page_num = response.url.split('/')[-1].split('=')[-1]
        file_name = 'script-yelp-pittsburgh-restaurants-%d.txt' % (int(page_num) / 10)
        with open(file_name, 'wb') as f:
            f.write(str(response.css('ul.ylist.ylist-bordered.search-results span.indexed-biz-name a.biz-name.js-analytics-click span::text').extract()))
        self.log('%s is saved.' % file_name)

process = CrawlerProcess({'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'})

process.crawl(ScriptRunSpider)
process.start(stop_after_crawl=True)
# Out:
# 2016-11-02 13:28:06 [scrapy] INFO: Scrapy 1.2.0 started (bot: scrapybot)
# 2016-11-02 13:28:06 [scrapy] INFO: Overridden settings: {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2016-11-02 13:28:06 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 13:28:06 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 13:28:06 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 13:28:06 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 13:28:06 [scrapy] INFO: Spider opened
# 2016-11-02 13:28:06 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 13:28:06 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-02 13:28:08 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=20> (referer: None)
# 2016-11-02 13:28:08 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=10> (referer: None)
# 2016-11-02 13:28:08 [scriptrunspider] DEBUG: script-yelp-pittsburgh-restaurants-2.txt is saved.
# 2016-11-02 13:28:08 [scriptrunspider] DEBUG: script-yelp-pittsburgh-restaurants-1.txt is saved.
# 2016-11-02 13:28:11 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0> (referer: None)
# 2016-11-02 13:28:11 [scriptrunspider] DEBUG: script-yelp-pittsburgh-restaurants-0.txt is saved.
# 2016-11-02 13:28:11 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 13:28:11 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 863,
#  'downloader/request_count': 3,
#  'downloader/request_method_count/GET': 3,
#  'downloader/response_bytes': 106557,
#  'downloader/response_count': 3,
#  'downloader/response_status_count/200': 3,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 17, 28, 11, 924633),
#  'log_count/DEBUG': 7,
#  'log_count/INFO': 7,
#  'response_received_count': 3,
#  'scheduler/dequeued': 3,
#  'scheduler/dequeued/memory': 3,
#  'scheduler/enqueued': 3,
#  'scheduler/enqueued/memory': 3,
#  'start_time': datetime.datetime(2016, 11, 2, 17, 28, 6, 434446)}
# 2016-11-02 13:28:11 [scrapy] INFO: Spider closed (finished)
# <DeferredList at 0x10568a050 current result: []>

# %%
# !cat script-yelp-pittsburgh-restaurants-0.txt
# !cat script-yelp-pittsburgh-restaurants-1.txt
# !cat script-yelp-pittsburgh-restaurants-2.txt
# Out:
# [u'Gaucho Parrilla Argentina', u't\xe4k\u014d', u'Las Palmas', u'Butcher and the Rye', u'Altius', u'Umbrella Cafe', u'The Twisted Frenchman', u'Legume', u'Smallman Galley', u'The Foundry Table & Tap'][u'Las Palmas Carniceria', u'Smallman Galley', u'Cop Out Pierogies', u'Eleven', u'B52 Cafe', u'Meat & Potatoes', u'Noodlehead', u'The Foundry Table & Tap', u'Cure', u'Penn Ave Fish Company'][u'Point Brugge Caf\xe9', u'Bakersfield Penn Ave', u'Alla Famiglia', u'Cafe\u2019 33', u'Apteka', u'Edgar Tacos Stand', u'Amazing Cafe', u'Proper Brick Oven & Tap Room', u'Cafe Du Jour', u'Peppi\u2019s']

# %% [markdown]
# ### Run multiple spiders in the same process
# Above we just tried to run a single spider per proces, now we will try to run multiple spiders in the same process.
#
# See below an example to run multiple spiders at the same time. **Also, please note if you want to execute following script after the execution of above code, you also need to relaunch the jupyter notebook since Reactor is not restartable.**

# %%
import scrapy
from twisted.internet import reactor
from scrapy.crawler import CrawlerRunner
from scrapy.utils.log import configure_logging

class Spider1(scrapy.Spider):
    name = "spider1" # name must be unique within project.
    
    def start_requests(self):
        urls = [
            'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            
    def parse(self, response):
        page_num = response.url.split('/')[-1].split('=')[-1]
        file_name = 'script-parallel-spider1.txt'
        with open(file_name, 'wb') as f:
            f.write(str(response.css('ul.ylist.ylist-bordered.search-results span.indexed-biz-name a.biz-name.js-analytics-click span::text').extract()))
        self.log('%s is saved.' % file_name)
        
class Spider2(scrapy.Spider):
    name = "spider2" # name must be unique within project.
    
    def start_requests(self):
        urls = [
            'https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=10',
        ]
        for url in urls:
            yield scrapy.Request(url=url, callback=self.parse)
            
    def parse(self, response):
        page_num = response.url.split('/')[-1].split('=')[-1]
        file_name = 'script-parallel-spider2.txt'
        with open(file_name, 'wb') as f:
            f.write(str(response.css('ul.ylist.ylist-bordered.search-results span.indexed-biz-name a.biz-name.js-analytics-click span::text').extract()))
        self.log('%s is saved.' % file_name)

configure_logging()
runner = CrawlerRunner()
runner.crawl(Spider1)
runner.crawl(Spider2)
d = runner.join()
d.addBoth(lambda _: reactor.stop())
reactor.run()
# Out:
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 14:59:11 [scrapy] INFO: Spider opened
# 2016-11-02 14:59:11 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 14:59:11 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6023
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled extensions:
# ['scrapy.extensions.logstats.LogStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.corestats.CoreStats']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.chunked.ChunkedTransferMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2016-11-02 14:59:11 [scrapy] INFO: Enabled item pipelines:
# []
# 2016-11-02 14:59:11 [scrapy] INFO: Spider opened
# 2016-11-02 14:59:11 [scrapy] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2016-11-02 14:59:11 [scrapy] DEBUG: Telnet console listening on 127.0.0.1:6024
# 2016-11-02 14:59:13 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=10> (referer: None)
# 2016-11-02 14:59:13 [spider2] DEBUG: script-parallel-spider2.txt is saved.
# 2016-11-02 14:59:13 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 14:59:13 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 271,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 35101,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 18, 59, 13, 926373),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 7,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 2, 18, 59, 11, 404670)}
# 2016-11-02 14:59:13 [scrapy] INFO: Spider closed (finished)
# 2016-11-02 14:59:13 [scrapy] DEBUG: Crawled (200) <GET https://www.yelp.com/search?find_desc=Restaurants&find_loc=Pittsburgh,+PA&start=0> (referer: None)
# 2016-11-02 14:59:14 [spider1] DEBUG: script-parallel-spider1.txt is saved.
# 2016-11-02 14:59:14 [scrapy] INFO: Closing spider (finished)
# 2016-11-02 14:59:14 [scrapy] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 270,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 38625,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2016, 11, 2, 18, 59, 14, 115908),
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 16,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2016, 11, 2, 18, 59, 11, 378709)}
# 2016-11-02 14:59:14 [scrapy] INFO: Spider closed (finished)

# %%
# !cat script-parallel-spider1.txt
# !cat script-parallel-spider2.txt
# Out:
# [u'Gaucho Parrilla Argentina', u't\xe4k\u014d', u'Las Palmas', u'Butcher and the Rye', u'Altius', u'Umbrella Cafe', u'The Twisted Frenchman', u'Legume', u'Smallman Galley', u'The Foundry Table & Tap'][u'Doce Taqueria', u'Meat & Potatoes', u'Eleven', u'Noodlehead', u'Cop Out Pierogies', u'Penn Ave Fish Company', u'Cure', u'Bakersfield Penn Ave', u'Las Palmas Carniceria', u'Ting\u2019s Kitchen']

# %% [markdown]
# ### Resources
#
# In case you are interested in knowing more about Scrapy, you can refer to following site. Some of the contents covered in this material is also inspired by following document.
#
# 1. Official document of Scrapy: https://doc.scrapy.org/en/latest/index.html
